# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadEgbaria1/deep-learning-project3/blob/main/HW3FINALFINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning: Assignment #3
# ## Submission date: 07/01/2026, 23:59.
# ### Topics:
# - RNNs
# - GRUs
# - LSTMs
# - Transformers

# %% [markdown]
# **Submitted by:**
#
# - Morad kutt 315818484
# - Ahmad Egbaria 212352504

# %% [markdown]
# **Assignment Instructions:**
#
# · Submissions are in **pairs only**. Write both names + IDs at the top of the notebook.
#
# · Keep your code **clean, concise, and readable**.
#
# · You may work in your IDE, but you **must** paste the final code back into the **matching notebook cells** and run it there.
#
#
# · <font color='red'>Write your textual answers in red.</font>
# (e.g., `<span style="color:red">your answer here</span>`)
#
# · All figures, printed results, and outputs should remain visible in the notebook.
# Run **all cells** before submitting and **do not clear outputs**.
#
# · Use relative paths — **no absolute file paths** pointing to local machines.
#
# · **Important:** Your submission must be entirely your own.
# Any form of plagiarism (including uncredited use of ChatGPT or AI tools) will result in **grade 0** and disciplinary action.

# %% [markdown]
# ## Question 1 — Chatbot Tutorial (35 Points)
#
# In this tutorial, we explore a classical and instructive application of
# **recurrent sequence-to-sequence (seq2seq) models**: building a neural
# chatbot. Chatbots provide a natural and intuitive testbed for studying
# sequence models, as they require processing variable-length input
# sequences and generating coherent variable-length outputs, one token at
# a time.
#
# Conversational agents are a long-standing and active research topic in
# artificial intelligence. Chatbots appear in a wide range of practical
# settings, including customer service systems, online helpdesks, and
# virtual assistants. Many deployed systems rely on **retrieval-based
# models**, which select responses from a predefined set based on the input
# query. While such approaches can be effective in narrowly defined
# domains, they lack the flexibility required for open-domain
# conversation.
#
# Teaching a machine to generate meaningful, context-aware responses
# across multiple domains remains a challenging and largely unsolved
# problem. The rise of deep learning has enabled a class of **generative
# conversational models**, most notably the *Neural Conversational Model*
# introduced by Vinyals and Le (2015), which demonstrated that an
# encoder–decoder architecture can be trained end-to-end to map input
# sentences directly to output sentences.
#
# Inspired by this line of work, we study a simplified generative chatbot
# implemented using modern deep learning tools.
#
# In this question, we will work with conversational data extracted from
# movie scripts in the
# [Cornell Movie-Dialogs Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html).
# Each training example consists of an input sentence and a corresponding
# response sentence, forming a paired sequence-to-sequence learning task.

# %% [markdown]
# ### Load & Preprocess Data

# %% [markdown]
# To start, we load the data. Download the data ZIP file
# [here](https://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip) and unzip it in the current directory, or alternalively run the following cell:

# %%
# !mkdir data
# !cd data
# !wget https://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip
# !unzip -q movie-corpus.zip
# !cd ..
# Out:
# --2026-01-16 13:59:34--  https://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip
# Resolving zissou.infosci.cornell.edu (zissou.infosci.cornell.edu)... 128.253.51.179
# Connecting to zissou.infosci.cornell.edu (zissou.infosci.cornell.edu)|128.253.51.179|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40854701 (39M) [application/zip]
# Saving to: ‘movie-corpus.zip’
#
# movie-corpus.zip    100%[===================>]  38.96M  35.4MB/s    in 1.1s
#
# 2026-01-16 13:59:35 (35.4 MB/s) - ‘movie-corpus.zip’ saved [40854701/40854701]

# %% [markdown]
# After loading the data, let’s import some necessities.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import json


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %% [markdown]
# The next step is to reformat our data file and load the data into
# structures that we can work with.
#
# The [Cornell Movie-Dialogs
# Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html)_
# is a rich dataset of movie character dialog:
#
# -  220,579 conversational exchanges between 10,292 pairs of movie
#    characters
# -  9,035 characters from 617 movies
# -  304,713 total utterances
#
# This dataset is large and diverse, and there is a great variation of
# language formality, time periods, sentiment, etc. Our hope is that this
# diversity makes our model robust to many forms of inputs and queries.
#
# First, we’ll take a look at some lines of our datafile to see the
# original format.

# %%
# !ls data

# %%
corpus = "movie-corpus"
corpus_name = "movie-corpus"

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "utterances.jsonl"))
# Out:
# b'{"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}\n'
# b'{"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}\n'
# b'{"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L925", "conversation_id": "L924", "text": "Let\'s go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "\'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}\n'
# b'{"id": "L924", "conversation_id": "L924", "text": "Wow", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Wow", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L872", "conversation_id": "L870", "text": "Okay -- you\'re gonna need to learn how to lie.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 4, "toks": [{"tok": "Okay", "tag": "UH", "dep": "intj", "up": 4, "dn": []}, {"tok": "--", "tag": ":", "dep": "punct", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "\'re", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "gon", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 2, 3, 6, 12]}, {"tok": "na", "tag": "TO", "dep": "aux", "up": 6, "dn": []}, {"tok": "need", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 8]}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 8, "dn": []}, {"tok": "learn", "tag": "VB", "dep": "xcomp", "up": 6, "dn": [7, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 11, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 11, "dn": []}, {"tok": "lie", "tag": "VB", "dep": "xcomp", "up": 8, "dn": [9, 10]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": "L871", "timestamp": null, "vectors": []}\n'
# b'{"id": "L871", "conversation_id": "L870", "text": "No", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "No", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": "L870", "timestamp": null, "vectors": []}\n'
# b'{"id": "L870", "conversation_id": "L870", "text": "I\'m kidding.  You know how sometimes you just become this \\"persona\\"?  And you don\'t know how to quit?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 2, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "\'m", "tag": "VBP", "dep": "aux", "up": 2, "dn": []}, {"tok": "kidding", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 3]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 2, "dn": [4]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 3, "dn": []}]}, {"rt": 1, "toks": [{"tok": "You", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "know", "tag": "VBP", "dep": "ROOT", "dn": [0, 6, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 3, "dn": []}, {"tok": "sometimes", "tag": "RB", "dep": "advmod", "up": 6, "dn": [2]}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 6, "dn": []}, {"tok": "just", "tag": "RB", "dep": "advmod", "up": 6, "dn": []}, {"tok": "become", "tag": "VBP", "dep": "ccomp", "up": 1, "dn": [3, 4, 5, 9]}, {"tok": "this", "tag": "DT", "dep": "det", "up": 9, "dn": []}, {"tok": "\\"", "tag": "``", "dep": "punct", "up": 9, "dn": []}, {"tok": "persona", "tag": "NN", "dep": "attr", "up": 6, "dn": [7, 8, 10]}, {"tok": "\\"", "tag": "\'\'", "dep": "punct", "up": 9, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": [12]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 11, "dn": []}]}, {"rt": 4, "toks": [{"tok": "And", "tag": "CC", "dep": "cc", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "n\'t", "tag": "RB", "dep": "neg", "up": 4, "dn": []}, {"tok": "know", "tag": "VB", "dep": "ROOT", "dn": [0, 1, 2, 3, 7, 8]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 7, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 7, "dn": []}, {"tok": "quit", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 6]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L869", "conversation_id": "L866", "text": "Like my fear of wearing pastels?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Like", "tag": "IN", "dep": "ROOT", "dn": [2, 6]}, {"tok": "my", "tag": "PRP$", "dep": "poss", "up": 2, "dn": []}, {"tok": "fear", "tag": "NN", "dep": "pobj", "up": 0, "dn": [1, 3]}, {"tok": "of", "tag": "IN", "dep": "prep", "up": 2, "dn": [4]}, {"tok": "wearing", "tag": "VBG", "dep": "pcomp", "up": 3, "dn": [5]}, {"tok": "pastels", "tag": "NNS", "dep": "dobj", "up": 4, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L868", "timestamp": null, "vectors": []}\n'

# %% [markdown]
# #### Create formatted data file

# %% [markdown]
# For convenience, we'll create a nicely formatted data file in which each line contains a tab-separated *query sentence* and a *response sentence* pair.
#
# The following functions facilitate the parsing of the raw
# *utterances.jsonl* data file.
#
#
# In the next cell, you'll find the functions:
# -  ``loadLinesAndConversations`` splits each line of the file into a dictionary of lines with fields: lineID, characterID, and text and then groups them into conversations with fields: conversationID, movieID, and lines.
#
# -  ``extractSentencePairs`` extracts pairs of sentences from
#    conversations.
#
#
# > Run the code in the next cell.

# %%
# Splits each line of the file to create lines and conversations
def loadLinesAndConversations(fileName):
    lines = {}
    conversations = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            lineJson = json.loads(line)
            # Extract fields for line object
            lineObj = {}
            lineObj["lineID"] = lineJson["id"]
            lineObj["characterID"] = lineJson["speaker"]
            lineObj["text"] = lineJson["text"]
            lines[lineObj['lineID']] = lineObj

            # Extract fields for conversation object
            if lineJson["conversation_id"] not in conversations:
                convObj = {}
                convObj["conversationID"] = lineJson["conversation_id"]
                convObj["movieID"] = lineJson["meta"]["movie_id"]
                convObj["lines"] = [lineObj]
            else:
                convObj = conversations[lineJson["conversation_id"]]
                convObj["lines"].insert(0, lineObj)
            conversations[convObj["conversationID"]] = convObj

    return lines, conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations.values():
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %% [markdown]
# Now we’ll call these functions and create the file. We’ll call it
# *formatted_movie_lines.txt*.

# %%
# Define path to new file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict and conversations dict
lines = {}
conversations = {}
# Load lines and conversations
print("\nProcessing corpus into lines and conversations...")
lines, conversations = loadLinesAndConversations(os.path.join(corpus, "utterances.jsonl"))

# Write new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b'They do to!\tThey do not!\n'
# b'She okay?\tI hope so.\n'
# b"Wow\tLet's go.\n"
# b'"I\'m kidding.  You know how sometimes you just become this ""persona""?  And you don\'t know how to quit?"\tNo\n'
# b"No\tOkay -- you're gonna need to learn how to lie.\n"
# b"I figured you'd get to the good stuff eventually.\tWhat good stuff?\n"
# b'What good stuff?\t"The ""real you""."\n'
# b'"The ""real you""."\tLike my fear of wearing pastels?\n'
# b'do you listen to this crap?\tWhat crap?\n'
# b"What crap?\tMe.  This endless ...blonde babble. I'm like, boring myself.\n"

# %% [markdown]
# #### Trim Data

# %% [markdown]
# We now move from raw text to a representation that a neural network can process.
# Our next task is to build a **vocabulary** and load the **query/response pairs**
# into memory.
#
# Unlike images, text does not come with an inherent mapping to a numerical space.
# A sequence model expects **integer token indices**, so we must define a mapping
# from each unique word in the dataset to a discrete index.
#
# To do this, we define a `Voc` (vocabulary) class that maintains:
#
# - `word2index`: a mapping from each word to an integer index
# - `index2word`: the inverse mapping from indices back to words
# - `word2count`: a frequency table used for trimming rare words
# - `num_words`: the current vocabulary size
#
# In addition, we reserve a small set of **special tokens**:
#
# - `PAD` for padding shorter sequences in a batch
# - `SOS` to mark the start of a sequence for the decoder
# - `EOS` to mark the end of a sequence
# - `UNK` to represent words that are not in the vocabulary
#
# Later, we will remove infrequent words from the vocabulary using a minimum
# frequency threshold (`MIN_COUNT`). This reduces noise and decreases the effective
# problem size, which often improves training stability and convergence.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token
UNK_token = 3  # Unknown word token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {
            PAD_token: "PAD",
            SOS_token: "SOS",
            EOS_token: "EOS",
            UNK_token: "UNK",
        }
        self.num_words = 4  # Count default tokens

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []
        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {
            PAD_token: "PAD",
            SOS_token: "SOS",
            EOS_token: "EOS",
            UNK_token: "UNK",
        }
        self.num_words = 4  # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# We begin by converting Unicode strings to ASCII using `unicodeToAscii`.
# Next, all text is lowercased and non-letter characters are removed while
# preserving basic punctuation (`normalizeString`).
# Finally, to promote stable training and reduce unnecessary computation,
# we filter out sentence pairs whose length exceeds the `MAX_LENGTH`
# threshold (`filterPairs`).

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

def readVocs(datafile, corpus_name):
    print("Reading lines...")
    lines = open(datafile, encoding='utf-8').read().strip().split('\n')
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs

save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)

print("\nSample pairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64313 sentence pairs
# Counting words...
# Counted words: 18083
#
# Sample pairs:
# ['they do to !', 'they do not !']
# ['she okay ?', 'i hope so .']
# ['wow', 'let s go .']
# ['what good stuff ?', 'the real you .']
# ['the real you .', 'like my fear of wearing pastels ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['have fun tonight ?', 'tons']

# %% [markdown]
# Another technique that often improves training efficiency is **trimming
# rarely used words** from the vocabulary. Intuitively, words that appear
# only a handful of times contribute little to the learning signal, while
# significantly increasing the size of the vocabulary.
#
# We perform trimming as a two-step process:
#
# 1. Remove words that appear fewer than `MIN_COUNT` times from the
#    vocabulary.
# 2. Remove sentence pairs that contain any of the trimmed words, ensuring
#    that all remaining training examples are fully represented in the
#    vocabulary.
#
# This procedure reduces noise, lowers the dimensionality of the problem,
# and often leads to faster and more stable convergence during training.

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(
        len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)
    ))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7833 / 18079 = 0.4333
# Trimmed from 64313 pairs to 53131, 0.8261 of total

# %% [markdown]
# ### Preparing Data for the Model

# %% [markdown]
# So far, we have transformed raw conversational text into a cleaned and
# trimmed set of *(input, response)* sentence pairs, along with a vocabulary
# that maps words to integer indices.
#
# However, neural sequence models do not operate directly on text. Instead,
# they expect **numerical tensors** as input. In this section, we convert
# our sentence pairs into padded tensors that can be efficiently processed
# by the encoder–decoder model.
#
# To accelerate training and make effective use of GPU parallelism, we will
# train the model using **mini-batches** rather than individual sentence
# pairs. This introduces an additional challenge: sentences within a batch
# may have different lengths.
#
# To handle variable-length sequences, we adopt the following conventions:
#
# - Sentences are converted to sequences of word indices and terminated
#   with an `EOS_token`.
# - All sequences in a batch are padded to the length of the longest
#   sequence using the `PAD_token`.
# - Batched input tensors are shaped as
#   **(max_sequence_length, batch_size)**,
#   so that each time step can be processed across all sequences in parallel.
#
# This layout is particularly convenient for recurrent models, which
# process input one time step at a time.

# %% [markdown]
# In addition to the padded input and target tensors, we also construct:
#
# - A **lengths tensor**, which stores the true (unpadded) length of each
#   input sequence. This will later be used to efficiently process variable-
#   length sequences.
# - A **binary mask tensor** for the target sequences, where padded positions
#   are marked with 0 and valid tokens with 1. This allows us to ignore padded
#   values when computing the training loss.
#
# The following helper functions implement this batching pipeline.

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index.get(word, UNK_token) for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))


def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m


# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths


# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max(len(indexes) for indexes in indexes_batch)
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len


# Returns all items for a given batch of sentence pairs
def batch2TrainData(voc, pair_batch):
    # Sort pairs by input sentence length (descending)
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)

    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])

    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len

# %% [markdown]
# ### Model Architecture

# %% [markdown]
# #### Sequence-to-Sequence Architecture
#
# The core of our chatbot is a **sequence-to-sequence (seq2seq)** model.
# The objective of a seq2seq model is to map a variable-length input
# sequence to a variable-length output sequence using a fixed-size neural
# network.
#
# [Sutskever et al. (2014)](https://arxiv.org/abs/1409.3215) demonstrated
# that this task can be accomplished by composing two recurrent neural
# networks:
#
# - An **encoder**, which processes the input sequence and compresses it
#   into an internal representation.
# - A **decoder**, which generates the output sequence one token at a time,
#   conditioned on the encoder’s representation.
#
# In the context of conversational modeling, the encoder reads the input
# sentence (the query), and the decoder generates the response.
#
# This encoder–decoder formulation underlies many modern sequence modeling
# approaches in machine translation, dialogue systems, and text
# generation.

# %% [markdown]
# #### Encoder
#
# In this part, you will implement the **encoder** component of the
# sequence-to-sequence model.
#
# The encoder processes the input sentence one token (word) at a time.
# At each time step, it produces an output vector and updates an internal
# **hidden state** that summarizes the sequence observed so far.
#
# You should implement the encoder using a **multi-layer Gated Recurrent
# Unit (GRU)**, introduced by [Cho et al. (2014)](https://arxiv.org/pdf/1406.1078v3.pdf).
# GRUs extend standard recurrent neural networks by incorporating gating
# mechanisms that regulate information flow, enabling more effective
# modeling of long-term dependencies.
#
# Your encoder should be **bidirectional**, meaning that the input sequence is processed both forward and backward in time. The outputs of the forward and backward GRUs should be **summed** at each time step to form the final encoder output representation.
#
# Before being passed to the GRU, word indices are mapped into a continuous vector space using an **embedding layer**, which is provided to the encoder. The embedding dimension is equal to the GRU hidden size.
#
# When processing padded mini-batches, you must correctly pack and unpack
# sequences using:
#
# - `nn.utils.rnn.pack_padded_sequence`
# - `nn.utils.rnn.pad_packed_sequence`
#
# This ensures that the GRU does not perform unnecessary computation over
# padding tokens.

# %% [markdown]
# **Encoder Inputs**
#
# - `input_seq`: Padded batch of input sentences
#   Shape: *(max_length, batch_size)*
#
# - `input_lengths`: True lengths of each sentence in the batch
#   Shape: *(batch_size)*
#
# **Encoder Outputs**
#
# - `outputs`: Output features from the last hidden layer of the GRU
#   (sum of bidirectional outputs)
#   Shape: *(max_length, batch_size, hidden_size)*
#
# - `hidden`: Final hidden state of the GRU
#   Shape: *(n_layers × num_directions, batch_size, hidden_size)*

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Bidirectional GRU
        self.gru = nn.GRU(
            hidden_size,
            hidden_size,
            n_layers,
            dropout=(0 if n_layers == 1 else dropout),
            bidirectional=True,
            batch_first=False
        )

    def forward(self, input_seq, input_lengths, hidden=None):
        # input_seq: (max_length, batch_size)
        # Embed input words
        embedded = self.embedding(input_seq)  # (max_length, batch_size, hidden_size)

        # Pack padded batch of sequences for RNN
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths.cpu(), enforce_sorted=True)

        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)

        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # outputs: (max_length, batch_size, hidden_size * 2)

        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, :, self.hidden_size:]
        # outputs: (max_length, batch_size, hidden_size)

        return outputs, hidden

# %% [markdown]
# #### Decoder with Attention
#
# The decoder generates the response sequence in a token-by-token manner.
# At each time step, it predicts the next word based on:
#
# - its current hidden state,
# - the previously generated word, and
# - a **context vector** computed from the encoder outputs.
#
# A limitation of vanilla seq2seq models is their reliance on a single
# fixed-length context vector to represent the entire input sequence.
# This bottleneck becomes particularly problematic for long input
# sentences.
#
# To address this issue, [Bahdanau et al. (2015)](https://arxiv.org/abs/1409.0473) introduced the **attention mechanism**, which allows the decoder to focus on different parts of the input sequence at each decoding step.
#
# [Luong et al. (2015)](https://arxiv.org/abs/1508.04025) later proposed
# **Global Attention**, in which the decoder attends to *all* encoder
# hidden states at every time step. Attention weights are computed using
# the decoder’s current hidden state and the encoder outputs via a
# parameterized **score function**.
#
# In this assignment, you will implement Luong-style global attention., which computes a soft alignment between the decoder state and the encoder outputs, producing a context vector that guides each decoding step.

# %% [markdown]
# At a given decoding step $t$, the attention mechanism computes an
# alignment score between the current decoder hidden state $h_t$ and each encoder output $\bar{h_s}$.
#
# Luong attention defines three possible **score functions**:
#
# - **Dot**:
#   $\text{score}(h_t, \bar{h}_s) = h_t^\top \bar{h}_s$
#
# - **General**:
#   $\text{score}(h_t, \bar{h}_s) = h_t^\top W \bar{h}_s$
#
# - **Concat**:
#   $\text{score}(h_t, \bar{h}_s) = v^\top \tanh(W [h_t ; \bar{h}_s])$
#
# The attention weights are obtained by applying a softmax over all encoder time steps. These weights are then used to compute a **context vector** as a weighted sum of encoder outputs.

# %%
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        self.hidden_size = hidden_size

        if method not in ['dot', 'general', 'concat']:
            raise ValueError(f"Attention method '{method}' is not valid. Choose from 'dot', 'general', 'concat'.")

        if self.method == 'general':
            self.attn = nn.Linear(hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_outputs):
        # hidden: (1, batch_size, hidden_size)
        # encoder_outputs: (max_length, batch_size, hidden_size)
        return torch.sum(hidden * encoder_outputs, dim=2)

    def general_score(self, hidden, encoder_outputs):
        energy = self.attn(encoder_outputs)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_outputs):
        # hidden: (1, batch_size, hidden_size) -> expand to (max_length, batch_size, hidden_size)
        hidden_expanded = hidden.expand(encoder_outputs.size(0), -1, -1)
        energy = self.attn(torch.cat((hidden_expanded, encoder_outputs), dim=2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # hidden: (1, batch_size, hidden_size)
        # encoder_outputs: (max_length, batch_size, hidden_size)

        # Calculate attention energies
        if self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)
        elif self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)

        # Transpose to (batch_size, max_length)
        attn_energies = attn_energies.t()

        # Return softmax normalized attention weights (batch_size, 1, max_length)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %% [markdown]
# #### Decoder with Luong Attention
#
# We now define the decoder. Unlike the encoder (which processes the entire input
# sequence in one forward pass), the decoder is executed **one time step at a time**:
# at each step it receives a single token and produces a probability distribution
# over the vocabulary for the next token.
#
# Concretely, at decoding step $t$:
#
# - The input to the decoder is a tensor `input_step` of shape **(1, batch_size)**,
#   containing one token per sequence.
# - After embedding, this becomes **(1, batch_size, hidden_size)**.
# - The decoder updates its hidden state using a unidirectional GRU.
#
# A standard seq2seq decoder compresses the entire input into a fixed vector, which can lead to information loss—especially for longer sequences. To address this, we incorporate an **attention mechanism**.
#
#
# We use **Luong et al. (2015)** global attention:
# [Luong et al., 2015](https://arxiv.org/abs/1508.04025).
# At each decoding step, the decoder computes attention weights over all encoder time steps, then uses these weights to form a context vector (a weighted sum of encoder outputs). This context vector summarizes the parts of the input sentence that are most relevant for predicting the next word.

# %% [markdown]
# At each decoding step, the decoder should:
#
# 1. Embed the current input token.
# 2. Run one GRU step to update the decoder hidden state.
# 3. Compute attention weights using the current decoder state and encoder outputs.
# 4. Use the attention weights to compute a context vector.
# 5. Combine the decoder state and context vector.
# 6. Predict a probability distribution over the vocabulary.
#
# You are asked to implement both the **initialization** and **forward pass** of the Luong attention decoder according to this description.
#
# ---
#
# **Inputs**
#
# - `input_step`: one time step (one token) for each sequence in the batch
#   Shape: **(1, batch_size)**
#
# - `last_hidden`: previous decoder hidden state
#   Shape: **(n_layers, batch_size, hidden_size)**
#
# - `encoder_outputs`: encoder outputs for all time steps
#   Shape: **(max_length, batch_size, hidden_size)**
#
# **Outputs**
#
# - `output`: probability distribution over the vocabulary for the next token
#   Shape: **(batch_size, voc.num_words)**
#
# - `hidden`: updated decoder hidden state
#   Shape: **(n_layers, batch_size, hidden_size)**

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(
            hidden_size,
            hidden_size,
            n_layers,
            dropout=(0 if n_layers == 1 else dropout)
        )
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # input_step: (1, batch_size)
        # last_hidden: (n_layers, batch_size, hidden_size)
        # encoder_outputs: (max_length, batch_size, hidden_size)

        # Get embedding of current input word
        embedded = self.embedding(input_step)  # (1, batch_size, hidden_size)
        embedded = self.embedding_dropout(embedded)

        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # rnn_output: (1, batch_size, hidden_size)

        # Calculate attention weights
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # attn_weights: (batch_size, 1, max_length)

        # Compute context vector as weighted sum of encoder outputs
        # encoder_outputs transposed: (batch_size, max_length, hidden_size)
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # context: (batch_size, 1, hidden_size)

        # Concatenate weighted context vector and GRU output
        rnn_output = rnn_output.squeeze(0)  # (batch_size, hidden_size)
        context = context.squeeze(1)        # (batch_size, hidden_size)
        concat_input = torch.cat((rnn_output, context), 1)  # (batch_size, hidden_size * 2)
        concat_output = torch.tanh(self.concat(concat_input))  # (batch_size, hidden_size)

        # Predict next word
        output = self.out(concat_output)  # (batch_size, output_size)
        output = F.softmax(output, dim=1)

        return output, hidden

# %% [markdown]
# ### Define Training Procedure

# %% [markdown]
# We now define the components required to train our seq2seq chatbot.
# Training is performed over mini-batches of padded sequences, which
# requires special care when computing the loss and updating model
# parameters.

# %% [markdown]
# #### Masked Loss
#
# Because batches contain padded sequences, not all positions in the target
# tensor correspond to valid words. We therefore compute the loss only over
# non-padding positions.
#
# The function below computes a **masked negative log-likelihood loss**,
# given the decoder’s output distribution, the target tokens, and a binary
# mask that indicates which positions are valid (i.e., not `PAD_token`).

# %%
def maskNLLLoss(inp, target, mask):
    """
    inp:    (batch_size, vocab_size) softmax probabilities
    target: (batch_size,) target token indices
    mask:   (batch_size,) boolean mask (True for valid tokens, False for PAD)
    """
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# #### Single Training Iteration
#
# We now describe a **single training iteration**, corresponding to one
# mini-batch update.
#
# During each iteration, we apply two commonly used techniques to improve
# training stability and convergence:
#
# - **Teacher forcing**: with some probability, the decoder receives the
#   ground-truth token as its next input instead of its own prediction.
#   This can significantly speed up training, but excessive teacher
#   forcing may lead to poor performance at inference time.
#
# - **Gradient clipping**: gradients are clipped to a maximum norm to
#   prevent the exploding gradient problem, which is particularly common
#   in recurrent neural networks.
#
# The sequence of operations for a single iteration is as follows:

# %% [markdown]
# #### Single Training Iteration (Implement)
#
# In this part you will implement a **single mini-batch update** for the
# seq2seq chatbot.
#
# You must handle two key ideas we covered in class:
#
# - **Teacher forcing**: with some probability, `teacher_forcing_ratio`, feed the ground-truth token as the next decoder input; otherwise, feed the model’s own prediction.
# - **Gradient clipping**: clip gradient norms to avoid exploding gradients in RNN training.
#
# Your implementation should follow this high-level sequence:

# %% [markdown]
# **Sequence of Operations**
#
# 1. Forward pass the input batch through the encoder.
# 2. Initialize the decoder input with `SOS_token` and the decoder hidden
#    state with the encoder’s final hidden state.
# 3. Decode one time step at a time:
#    - apply teacher forcing with probability `teacher_forcing_ratio`
#    - otherwise, feed the decoder’s own prediction as the next input
# 4. Compute and accumulate masked loss.
# 5. Backpropagate gradients.
# 6. Clip gradients.

# %% [markdown]
# Complete the function `train(...)` so that it performs one full mini-batch training update according to the sequence of operations described abov

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len,
          encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer,
          batch_size, clip, max_length=MAX_LENGTH):
    """
    Performs a single mini-batch update step.
    """
    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Move tensors to the correct device
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    lengths = lengths.to("cpu")  # required by pack_padded_sequence

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]]).to(device)

    # Set initial decoder hidden state to encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = (random.random() < teacher_forcing_ratio)

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]]).to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropagation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    # Return average loss per non-pad token
    return sum(print_losses) / n_totals

# %% [markdown]
# #### Training Loop
#
# We now wrap the single training iteration into a full training loop.
# At each iteration, a random mini-batch is sampled and one parameter
# update is performed.
#
# We periodically print training statistics and save model checkpoints,
# which include the encoder and decoder parameters, optimizer states, and
# vocabulary information.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
               embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration,
               batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    training_batches = [
        batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
        for _ in range(n_iteration)
    ]

    print('Initializing ...')
    start_iteration = 1
    print_loss = 0

    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        input_variable, lengths, target_variable, mask, max_target_len = training_batches[iteration - 1]

        loss = train(input_variable, lengths, target_variable, mask, max_target_len,
                     encoder, decoder, embedding,
                     encoder_optimizer, decoder_optimizer,
                     batch_size, clip)

        print_loss += loss

        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print(f"Iteration: {iteration}; Percent complete: {iteration / n_iteration * 100:.1f}%; Average loss: {print_loss_avg:.4f}")
            print_loss = 0

        if iteration % save_every == 0:
            directory = os.path.join(
                save_dir, model_name, corpus_name,
                f'{encoder_n_layers}-{decoder_n_layers}_{hidden_size}'
            )
            os.makedirs(directory, exist_ok=True)

            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, f'{iteration}_checkpoint.tar'))

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# After training the chatbot model, we would like to interact with it and
# generate responses to user-provided input sentences. To do so, we must
# define how the decoder generates an output sequence from the encoded
# input.
#
# During training, the decoder may receive ground-truth tokens as input
# (teacher forcing). During evaluation, however, the model must rely
# entirely on its own predictions. This requires defining an explicit
# **decoding strategy**.

# %% [markdown]
# #### Greedy Decoding
#
# We use **greedy decoding** to generate responses at evaluation time.
# At each decoding step, greedy decoding selects the word with the highest predicted probability from the decoder’s output distribution.
#
# Formally, given the decoder output distribution at time step $t$,
# greedy decoding chooses:
#
# $$
# \hat{w}_t = \arg\max_w \; p(w \mid w_{<t}, x)
# $$
#
# Greedy decoding is optimal at the level of individual time steps, though it does not guarantee a globally optimal sequence. Despite this
# limitation, it is simple, efficient, and serves as a strong baseline for sequence generation.

# %% [markdown]
# To implement greedy decoding, we define a `GreedySearchDecoder` module.
# This module wraps the encoder and decoder and performs decoding one time step at a time.
#
# Given an input sentence, decoding proceeds as follows:
#
# **Computation Graph**
#
# 1. Forward the input sequence through the encoder.
# 2. Initialize the decoder hidden state using the encoder’s final hidden state.
# 3. Initialize the decoder input with the `SOS_token`.
# 4. Iteratively decode one token at a time:
#    - Forward pass through the decoder.
#    - Select the most probable token.
#    - Feed the selected token as input to the next step.
# 5. Collect and return the generated tokens and their scores.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# #### Evaluating Text Input
#
# With the decoding procedure defined, we can now evaluate individual input sentences.
#
# The `evaluate` function handles the low-level mechanics of evaluation:
# it converts an input sentence into a tensor of word indices, prepares the appropriate length tensor, and runs greedy decoding to obtain the outputn sequence.
#
# The `evaluateInput` function provides a simple interactive interface for the chatbot. It repeatedly prompts the user for input, normalizes the sentence using the same preprocessing pipeline as the training data, and prints the decoded response. The interaction continues until the user enters `"q"` or `"quit"`.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    """
    Evaluate a single input sentence using greedy decoding.
    Out-of-vocabulary words are mapped to UNK_token.
    """
    # words -> indexes (UNK-safe)
    indexes = [
        voc.word2index.get(word, UNK_token)
        for word in sentence.split(' ')
    ] + [EOS_token]

    indexes_batch = [indexes]

    # Create lengths tensor
    lengths = torch.tensor([len(indexes)])

    # Prepare input batch (max_length, batch_size=1)
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")

    # Decode sentence
    tokens, scores = searcher(input_batch, lengths, max_length)

    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    """
    Interactive chatbot interface.
    Type 'q' or 'quit' to exit.
    """
    while True:
        # Get input sentence
        input_sentence = input('> ')
        if input_sentence in ('q', 'quit'):
            break

        # Normalize input
        input_sentence = normalizeString(input_sentence)

        # Evaluate sentence
        output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)

        # Remove EOS and PAD tokens from output
        output_words = [w for w in output_words if w not in ('EOS', 'PAD')]

        print('Bot:', ' '.join(output_words))

# %% [markdown]
# ### Run Model

# %% [markdown]
# Finally, it is time to run our model!
#
# Regardless of whether we want to train or test the chatbot model, we
# must initialize the individual encoder and decoder models. In the
# following block, we set our desired configurations, choose to start from scratch or set a checkpoint to load from, and build and initialize the models. Feel free to play with different model configurations to
# optimize performance.

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#attn_model = 'general'
#attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000
#loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# #### Run Training
#
# Run the following block in order to train the model.
#
# First we set training parameters, then we initialize our optimizers, and finally we call the ``trainIters`` function to run our training
# iterations.

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
print_every = 1
save_every = 500

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have cuda, configure cuda to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.9719
# Iteration: 2; Percent complete: 0.1%; Average loss: 8.8493
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.6736
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.3868
# Iteration: 5; Percent complete: 0.1%; Average loss: 7.8828
# Iteration: 6; Percent complete: 0.1%; Average loss: 7.3495
# Iteration: 7; Percent complete: 0.2%; Average loss: 6.9060
# Iteration: 8; Percent complete: 0.2%; Average loss: 6.7052
# Iteration: 9; Percent complete: 0.2%; Average loss: 6.8014
# Iteration: 10; Percent complete: 0.2%; Average loss: 6.5041
# Iteration: 11; Percent complete: 0.3%; Average loss: 6.3684
# Iteration: 12; Percent complete: 0.3%; Average loss: 5.8387
# Iteration: 13; Percent complete: 0.3%; Average loss: 5.6003
# Iteration: 14; Percent complete: 0.4%; Average loss: 5.4170
# Iteration: 15; Percent complete: 0.4%; Average loss: 5.5425
# Iteration: 16; Percent complete: 0.4%; Average loss: 5.4153
# Iteration: 17; Percent complete: 0.4%; Average loss: 5.6101
# Iteration: 18; Percent complete: 0.4%; Average loss: 4.9410
# Iteration: 19; Percent complete: 0.5%; Average loss: 5.0615
# Iteration: 20; Percent complete: 0.5%; Average loss: 5.0025
# Iteration: 21; Percent complete: 0.5%; Average loss: 4.9014
# Iteration: 22; Percent complete: 0.5%; Average loss: 4.8129
# Iteration: 23; Percent complete: 0.6%; Average loss: 5.1151
# Iteration: 24; Percent complete: 0.6%; Average loss: 4.9388
# Iteration: 25; Percent complete: 0.6%; Average loss: 4.8301
# Iteration: 26; Percent complete: 0.7%; Average loss: 4.8634
# Iteration: 27; Percent complete: 0.7%; Average loss: 4.9099
# Iteration: 28; Percent complete: 0.7%; Average loss: 4.7636
# Iteration: 29; Percent complete: 0.7%; Average loss: 4.9628
# Iteration: 30; Percent complete: 0.8%; Average loss: 4.8650
# Iteration: 31; Percent complete: 0.8%; Average loss: 4.6133
# Iteration: 32; Percent complete: 0.8%; Average loss: 4.8440
# Iteration: 33; Percent complete: 0.8%; Average loss: 4.9073
# Iteration: 34; Percent complete: 0.9%; Average loss: 4.6566
# Iteration: 35; Percent complete: 0.9%; Average loss: 4.6757
# Iteration: 36; Percent complete: 0.9%; Average loss: 4.8370
# Iteration: 37; Percent complete: 0.9%; Average loss: 4.9342
# Iteration: 38; Percent complete: 0.9%; Average loss: 4.9415
# Iteration: 39; Percent complete: 1.0%; Average loss: 4.8938
# Iteration: 40; Percent complete: 1.0%; Average loss: 4.5641
# Iteration: 41; Percent complete: 1.0%; Average loss: 4.7068
# Iteration: 42; Percent complete: 1.1%; Average loss: 4.6390
# Iteration: 43; Percent complete: 1.1%; Average loss: 4.6906
# Iteration: 44; Percent complete: 1.1%; Average loss: 4.6222
# Iteration: 45; Percent complete: 1.1%; Average loss: 4.5757
# Iteration: 46; Percent complete: 1.1%; Average loss: 4.7005
# Iteration: 47; Percent complete: 1.2%; Average loss: 4.8991
# Iteration: 48; Percent complete: 1.2%; Average loss: 4.6443
# Iteration: 49; Percent complete: 1.2%; Average loss: 4.7974
# Iteration: 50; Percent complete: 1.2%; Average loss: 4.5647
# Iteration: 51; Percent complete: 1.3%; Average loss: 4.7829
# Iteration: 52; Percent complete: 1.3%; Average loss: 4.5579
# Iteration: 53; Percent complete: 1.3%; Average loss: 4.3115
# Iteration: 54; Percent complete: 1.4%; Average loss: 4.5891
# Iteration: 55; Percent complete: 1.4%; Average loss: 4.4396
# Iteration: 56; Percent complete: 1.4%; Average loss: 4.5115
# Iteration: 57; Percent complete: 1.4%; Average loss: 4.4270
# Iteration: 58; Percent complete: 1.5%; Average loss: 4.6788
# Iteration: 59; Percent complete: 1.5%; Average loss: 4.4471
# Iteration: 60; Percent complete: 1.5%; Average loss: 4.5109
# Iteration: 61; Percent complete: 1.5%; Average loss: 4.6038
# Iteration: 62; Percent complete: 1.6%; Average loss: 4.4691
# Iteration: 63; Percent complete: 1.6%; Average loss: 4.7411
# Iteration: 64; Percent complete: 1.6%; Average loss: 4.6621
# Iteration: 65; Percent complete: 1.6%; Average loss: 4.5749
# Iteration: 66; Percent complete: 1.7%; Average loss: 4.3862
# Iteration: 67; Percent complete: 1.7%; Average loss: 4.4776
# Iteration: 68; Percent complete: 1.7%; Average loss: 4.5853
# Iteration: 69; Percent complete: 1.7%; Average loss: 4.3879
# Iteration: 70; Percent complete: 1.8%; Average loss: 4.5187
# Iteration: 71; Percent complete: 1.8%; Average loss: 4.3908
# Iteration: 72; Percent complete: 1.8%; Average loss: 4.4159
# Iteration: 73; Percent complete: 1.8%; Average loss: 4.3377
# Iteration: 74; Percent complete: 1.8%; Average loss: 4.5696
# Iteration: 75; Percent complete: 1.9%; Average loss: 4.5650
# Iteration: 76; Percent complete: 1.9%; Average loss: 4.7041
# Iteration: 77; Percent complete: 1.9%; Average loss: 4.4668
# Iteration: 78; Percent complete: 1.9%; Average loss: 4.4636
# Iteration: 79; Percent complete: 2.0%; Average loss: 4.5138
# Iteration: 80; Percent complete: 2.0%; Average loss: 4.5159
# Iteration: 81; Percent complete: 2.0%; Average loss: 4.5108
# Iteration: 82; Percent complete: 2.1%; Average loss: 4.3375
# Iteration: 83; Percent complete: 2.1%; Average loss: 4.3882
# Iteration: 84; Percent complete: 2.1%; Average loss: 4.1637
# Iteration: 85; Percent complete: 2.1%; Average loss: 4.2767
# Iteration: 86; Percent complete: 2.1%; Average loss: 4.5273
# Iteration: 87; Percent complete: 2.2%; Average loss: 4.7213
# Iteration: 88; Percent complete: 2.2%; Average loss: 4.5212
# Iteration: 89; Percent complete: 2.2%; Average loss: 4.5222
# Iteration: 90; Percent complete: 2.2%; Average loss: 4.6903
# Iteration: 91; Percent complete: 2.3%; Average loss: 4.5884
# Iteration: 92; Percent complete: 2.3%; Average loss: 4.3478
# Iteration: 93; Percent complete: 2.3%; Average loss: 4.3334
# Iteration: 94; Percent complete: 2.4%; Average loss: 4.1958
# Iteration: 95; Percent complete: 2.4%; Average loss: 4.2768
# Iteration: 96; Percent complete: 2.4%; Average loss: 4.5218
# Iteration: 97; Percent complete: 2.4%; Average loss: 4.7129
# Iteration: 98; Percent complete: 2.5%; Average loss: 4.5180
# Iteration: 99; Percent complete: 2.5%; Average loss: 4.4171
# Iteration: 100; Percent complete: 2.5%; Average loss: 4.3163
# Iteration: 101; Percent complete: 2.5%; Average loss: 4.3870
# Iteration: 102; Percent complete: 2.5%; Average loss: 4.6595
# Iteration: 103; Percent complete: 2.6%; Average loss: 4.4657
# Iteration: 104; Percent complete: 2.6%; Average loss: 4.2953
# Iteration: 105; Percent complete: 2.6%; Average loss: 4.4792
# Iteration: 106; Percent complete: 2.6%; Average loss: 4.5235
# Iteration: 107; Percent complete: 2.7%; Average loss: 4.2031
# Iteration: 108; Percent complete: 2.7%; Average loss: 4.2578
# Iteration: 109; Percent complete: 2.7%; Average loss: 4.3285
# Iteration: 110; Percent complete: 2.8%; Average loss: 4.4253
# Iteration: 111; Percent complete: 2.8%; Average loss: 4.4288
# Iteration: 112; Percent complete: 2.8%; Average loss: 4.2509
# Iteration: 113; Percent complete: 2.8%; Average loss: 4.2011
# Iteration: 114; Percent complete: 2.9%; Average loss: 4.3902
# Iteration: 115; Percent complete: 2.9%; Average loss: 4.4828
# Iteration: 116; Percent complete: 2.9%; Average loss: 4.1856
# Iteration: 117; Percent complete: 2.9%; Average loss: 4.4909
# Iteration: 118; Percent complete: 2.9%; Average loss: 4.4213
# Iteration: 119; Percent complete: 3.0%; Average loss: 4.3706
# Iteration: 120; Percent complete: 3.0%; Average loss: 4.3993
# Iteration: 121; Percent complete: 3.0%; Average loss: 4.1816
# Iteration: 122; Percent complete: 3.0%; Average loss: 4.4201
# Iteration: 123; Percent complete: 3.1%; Average loss: 4.1615
# Iteration: 124; Percent complete: 3.1%; Average loss: 4.3687
# Iteration: 125; Percent complete: 3.1%; Average loss: 4.2740
# Iteration: 126; Percent complete: 3.1%; Average loss: 4.4604
# Iteration: 127; Percent complete: 3.2%; Average loss: 4.1992
# Iteration: 128; Percent complete: 3.2%; Average loss: 4.1270
# Iteration: 129; Percent complete: 3.2%; Average loss: 4.2581
# Iteration: 130; Percent complete: 3.2%; Average loss: 4.1592
# Iteration: 131; Percent complete: 3.3%; Average loss: 4.3124
# Iteration: 132; Percent complete: 3.3%; Average loss: 4.2879
# Iteration: 133; Percent complete: 3.3%; Average loss: 4.3736
# Iteration: 134; Percent complete: 3.4%; Average loss: 3.9789
# Iteration: 135; Percent complete: 3.4%; Average loss: 4.3038
# Iteration: 136; Percent complete: 3.4%; Average loss: 4.4686
# Iteration: 137; Percent complete: 3.4%; Average loss: 4.1107
# Iteration: 138; Percent complete: 3.5%; Average loss: 4.2955
# Iteration: 139; Percent complete: 3.5%; Average loss: 4.2774
# Iteration: 140; Percent complete: 3.5%; Average loss: 4.1980
# Iteration: 141; Percent complete: 3.5%; Average loss: 4.3853
# Iteration: 142; Percent complete: 3.5%; Average loss: 4.4151
# Iteration: 143; Percent complete: 3.6%; Average loss: 4.1599
# Iteration: 144; Percent complete: 3.6%; Average loss: 4.5341
# Iteration: 145; Percent complete: 3.6%; Average loss: 4.4918
# Iteration: 146; Percent complete: 3.6%; Average loss: 4.1658
# Iteration: 147; Percent complete: 3.7%; Average loss: 4.3234
# Iteration: 148; Percent complete: 3.7%; Average loss: 4.2712
# Iteration: 149; Percent complete: 3.7%; Average loss: 4.3241
# Iteration: 150; Percent complete: 3.8%; Average loss: 4.4454
# Iteration: 151; Percent complete: 3.8%; Average loss: 4.3594
# Iteration: 152; Percent complete: 3.8%; Average loss: 4.2317
# Iteration: 153; Percent complete: 3.8%; Average loss: 4.3248
# Iteration: 154; Percent complete: 3.9%; Average loss: 4.1714
# Iteration: 155; Percent complete: 3.9%; Average loss: 4.3353
# Iteration: 156; Percent complete: 3.9%; Average loss: 4.4287
# Iteration: 157; Percent complete: 3.9%; Average loss: 4.2676
# Iteration: 158; Percent complete: 4.0%; Average loss: 3.9278
# Iteration: 159; Percent complete: 4.0%; Average loss: 4.0030
# Iteration: 160; Percent complete: 4.0%; Average loss: 4.2060
# Iteration: 161; Percent complete: 4.0%; Average loss: 4.1513
# Iteration: 162; Percent complete: 4.0%; Average loss: 4.3383
# Iteration: 163; Percent complete: 4.1%; Average loss: 4.2517
# Iteration: 164; Percent complete: 4.1%; Average loss: 4.2923
# Iteration: 165; Percent complete: 4.1%; Average loss: 4.2147
# Iteration: 166; Percent complete: 4.2%; Average loss: 4.1977
# Iteration: 167; Percent complete: 4.2%; Average loss: 4.0768
# Iteration: 168; Percent complete: 4.2%; Average loss: 3.9049
# Iteration: 169; Percent complete: 4.2%; Average loss: 3.9953
# Iteration: 170; Percent complete: 4.2%; Average loss: 4.2320
# Iteration: 171; Percent complete: 4.3%; Average loss: 4.3881
# Iteration: 172; Percent complete: 4.3%; Average loss: 4.0369
# Iteration: 173; Percent complete: 4.3%; Average loss: 4.0671
# Iteration: 174; Percent complete: 4.3%; Average loss: 4.2500
# Iteration: 175; Percent complete: 4.4%; Average loss: 4.2549
# Iteration: 176; Percent complete: 4.4%; Average loss: 4.0920
# Iteration: 177; Percent complete: 4.4%; Average loss: 4.2272
# Iteration: 178; Percent complete: 4.5%; Average loss: 3.9795
# Iteration: 179; Percent complete: 4.5%; Average loss: 4.0951
# Iteration: 180; Percent complete: 4.5%; Average loss: 4.1464
# Iteration: 181; Percent complete: 4.5%; Average loss: 4.3564
# Iteration: 182; Percent complete: 4.5%; Average loss: 4.2530
# Iteration: 183; Percent complete: 4.6%; Average loss: 4.1924
# Iteration: 184; Percent complete: 4.6%; Average loss: 4.1294
# Iteration: 185; Percent complete: 4.6%; Average loss: 4.1505
# Iteration: 186; Percent complete: 4.7%; Average loss: 4.2162
# Iteration: 187; Percent complete: 4.7%; Average loss: 3.9338
# Iteration: 188; Percent complete: 4.7%; Average loss: 4.0133
# Iteration: 189; Percent complete: 4.7%; Average loss: 3.9603
# Iteration: 190; Percent complete: 4.8%; Average loss: 4.0419
# Iteration: 191; Percent complete: 4.8%; Average loss: 4.0708
# Iteration: 192; Percent complete: 4.8%; Average loss: 4.2306
# Iteration: 193; Percent complete: 4.8%; Average loss: 3.7869
# Iteration: 194; Percent complete: 4.9%; Average loss: 4.0296
# Iteration: 195; Percent complete: 4.9%; Average loss: 4.0269
# Iteration: 196; Percent complete: 4.9%; Average loss: 4.1599
# Iteration: 197; Percent complete: 4.9%; Average loss: 4.1858
# Iteration: 198; Percent complete: 5.0%; Average loss: 4.2682
# Iteration: 199; Percent complete: 5.0%; Average loss: 4.0739
# Iteration: 200; Percent complete: 5.0%; Average loss: 4.0806
# Iteration: 201; Percent complete: 5.0%; Average loss: 4.1964
# Iteration: 202; Percent complete: 5.1%; Average loss: 4.1128
# Iteration: 203; Percent complete: 5.1%; Average loss: 4.0644
# Iteration: 204; Percent complete: 5.1%; Average loss: 3.9572
# Iteration: 205; Percent complete: 5.1%; Average loss: 4.2914
# Iteration: 206; Percent complete: 5.1%; Average loss: 4.2808
# Iteration: 207; Percent complete: 5.2%; Average loss: 4.0297
# Iteration: 208; Percent complete: 5.2%; Average loss: 4.0490
# Iteration: 209; Percent complete: 5.2%; Average loss: 4.0443
# Iteration: 210; Percent complete: 5.2%; Average loss: 3.8515
# Iteration: 211; Percent complete: 5.3%; Average loss: 3.9991
# Iteration: 212; Percent complete: 5.3%; Average loss: 4.5119
# Iteration: 213; Percent complete: 5.3%; Average loss: 3.9226
# Iteration: 214; Percent complete: 5.3%; Average loss: 4.2284
# Iteration: 215; Percent complete: 5.4%; Average loss: 4.1395
# Iteration: 216; Percent complete: 5.4%; Average loss: 4.0337
# Iteration: 217; Percent complete: 5.4%; Average loss: 3.9602
# Iteration: 218; Percent complete: 5.5%; Average loss: 4.0312
# Iteration: 219; Percent complete: 5.5%; Average loss: 4.0234
# Iteration: 220; Percent complete: 5.5%; Average loss: 4.1540
# Iteration: 221; Percent complete: 5.5%; Average loss: 4.1125
# Iteration: 222; Percent complete: 5.5%; Average loss: 4.4146
# Iteration: 223; Percent complete: 5.6%; Average loss: 4.2880
# Iteration: 224; Percent complete: 5.6%; Average loss: 4.1803
# Iteration: 225; Percent complete: 5.6%; Average loss: 4.0335
# Iteration: 226; Percent complete: 5.7%; Average loss: 4.1306
# Iteration: 227; Percent complete: 5.7%; Average loss: 4.2824
# Iteration: 228; Percent complete: 5.7%; Average loss: 3.9756
# Iteration: 229; Percent complete: 5.7%; Average loss: 3.9226
# Iteration: 230; Percent complete: 5.8%; Average loss: 4.0627
# Iteration: 231; Percent complete: 5.8%; Average loss: 4.0802
# Iteration: 232; Percent complete: 5.8%; Average loss: 4.2019
# Iteration: 233; Percent complete: 5.8%; Average loss: 4.0172
# Iteration: 234; Percent complete: 5.9%; Average loss: 4.1767
# Iteration: 235; Percent complete: 5.9%; Average loss: 4.0937
# Iteration: 236; Percent complete: 5.9%; Average loss: 4.1517
# Iteration: 237; Percent complete: 5.9%; Average loss: 4.0406
# Iteration: 238; Percent complete: 5.9%; Average loss: 4.0248
# Iteration: 239; Percent complete: 6.0%; Average loss: 4.1007
# Iteration: 240; Percent complete: 6.0%; Average loss: 3.9145
# Iteration: 241; Percent complete: 6.0%; Average loss: 4.0115
# Iteration: 242; Percent complete: 6.0%; Average loss: 3.8333
# Iteration: 243; Percent complete: 6.1%; Average loss: 4.1516
# Iteration: 244; Percent complete: 6.1%; Average loss: 3.9495
# Iteration: 245; Percent complete: 6.1%; Average loss: 4.1410
# Iteration: 246; Percent complete: 6.2%; Average loss: 3.8594
# Iteration: 247; Percent complete: 6.2%; Average loss: 3.8019
# Iteration: 248; Percent complete: 6.2%; Average loss: 4.1883
# Iteration: 249; Percent complete: 6.2%; Average loss: 4.0293
# Iteration: 250; Percent complete: 6.2%; Average loss: 3.8952
# Iteration: 251; Percent complete: 6.3%; Average loss: 4.1972
# Iteration: 252; Percent complete: 6.3%; Average loss: 3.6704
# Iteration: 253; Percent complete: 6.3%; Average loss: 3.8932
# Iteration: 254; Percent complete: 6.3%; Average loss: 3.8278
# Iteration: 255; Percent complete: 6.4%; Average loss: 3.9783
# Iteration: 256; Percent complete: 6.4%; Average loss: 3.7043
# Iteration: 257; Percent complete: 6.4%; Average loss: 3.9468
# Iteration: 258; Percent complete: 6.5%; Average loss: 4.1194
# Iteration: 259; Percent complete: 6.5%; Average loss: 3.8986
# Iteration: 260; Percent complete: 6.5%; Average loss: 4.2130
# Iteration: 261; Percent complete: 6.5%; Average loss: 3.9865
# Iteration: 262; Percent complete: 6.6%; Average loss: 3.8774
# Iteration: 263; Percent complete: 6.6%; Average loss: 3.7307
# Iteration: 264; Percent complete: 6.6%; Average loss: 4.2269
# Iteration: 265; Percent complete: 6.6%; Average loss: 3.9671
# Iteration: 266; Percent complete: 6.7%; Average loss: 4.0787
# Iteration: 267; Percent complete: 6.7%; Average loss: 3.8452
# Iteration: 268; Percent complete: 6.7%; Average loss: 4.0085
# Iteration: 269; Percent complete: 6.7%; Average loss: 3.9227
# Iteration: 270; Percent complete: 6.8%; Average loss: 3.8685
# Iteration: 271; Percent complete: 6.8%; Average loss: 4.0514
# Iteration: 272; Percent complete: 6.8%; Average loss: 3.4991
# Iteration: 273; Percent complete: 6.8%; Average loss: 3.9671
# Iteration: 274; Percent complete: 6.9%; Average loss: 3.8097
# Iteration: 275; Percent complete: 6.9%; Average loss: 3.9649
# Iteration: 276; Percent complete: 6.9%; Average loss: 3.8838
# Iteration: 277; Percent complete: 6.9%; Average loss: 3.9052
# Iteration: 278; Percent complete: 7.0%; Average loss: 3.9210
# Iteration: 279; Percent complete: 7.0%; Average loss: 3.7210
# Iteration: 280; Percent complete: 7.0%; Average loss: 3.8048
# Iteration: 281; Percent complete: 7.0%; Average loss: 3.7007
# Iteration: 282; Percent complete: 7.0%; Average loss: 3.9159
# Iteration: 283; Percent complete: 7.1%; Average loss: 3.8042
# Iteration: 284; Percent complete: 7.1%; Average loss: 3.8924
# Iteration: 285; Percent complete: 7.1%; Average loss: 4.0383
# Iteration: 286; Percent complete: 7.1%; Average loss: 3.8403
# Iteration: 287; Percent complete: 7.2%; Average loss: 3.9496
# Iteration: 288; Percent complete: 7.2%; Average loss: 3.9294
# Iteration: 289; Percent complete: 7.2%; Average loss: 4.1252
# Iteration: 290; Percent complete: 7.2%; Average loss: 4.0733
# Iteration: 291; Percent complete: 7.3%; Average loss: 4.0163
# Iteration: 292; Percent complete: 7.3%; Average loss: 3.9275
# Iteration: 293; Percent complete: 7.3%; Average loss: 4.0106
# Iteration: 294; Percent complete: 7.3%; Average loss: 3.7987
# Iteration: 295; Percent complete: 7.4%; Average loss: 3.7830
# Iteration: 296; Percent complete: 7.4%; Average loss: 3.6980
# Iteration: 297; Percent complete: 7.4%; Average loss: 3.9308
# Iteration: 298; Percent complete: 7.4%; Average loss: 3.8853
# Iteration: 299; Percent complete: 7.5%; Average loss: 3.8819
# Iteration: 300; Percent complete: 7.5%; Average loss: 3.8982
# Iteration: 301; Percent complete: 7.5%; Average loss: 3.7781
# Iteration: 302; Percent complete: 7.5%; Average loss: 3.5735
# Iteration: 303; Percent complete: 7.6%; Average loss: 3.8587
# Iteration: 304; Percent complete: 7.6%; Average loss: 4.0079
# Iteration: 305; Percent complete: 7.6%; Average loss: 3.7583
# Iteration: 306; Percent complete: 7.6%; Average loss: 3.8370
# Iteration: 307; Percent complete: 7.7%; Average loss: 4.1182
# Iteration: 308; Percent complete: 7.7%; Average loss: 3.8263
# Iteration: 309; Percent complete: 7.7%; Average loss: 3.6350
# Iteration: 310; Percent complete: 7.8%; Average loss: 3.6693
# Iteration: 311; Percent complete: 7.8%; Average loss: 4.0934
# Iteration: 312; Percent complete: 7.8%; Average loss: 3.5924
# Iteration: 313; Percent complete: 7.8%; Average loss: 3.9538
# Iteration: 314; Percent complete: 7.8%; Average loss: 4.0478
# Iteration: 315; Percent complete: 7.9%; Average loss: 3.7864
# Iteration: 316; Percent complete: 7.9%; Average loss: 3.9120
# Iteration: 317; Percent complete: 7.9%; Average loss: 3.9052
# Iteration: 318; Percent complete: 8.0%; Average loss: 3.7839
# Iteration: 319; Percent complete: 8.0%; Average loss: 3.6852
# Iteration: 320; Percent complete: 8.0%; Average loss: 3.8553
# Iteration: 321; Percent complete: 8.0%; Average loss: 3.6292
# Iteration: 322; Percent complete: 8.1%; Average loss: 3.9265
# Iteration: 323; Percent complete: 8.1%; Average loss: 3.9848
# Iteration: 324; Percent complete: 8.1%; Average loss: 3.7844
# Iteration: 325; Percent complete: 8.1%; Average loss: 3.5491
# Iteration: 326; Percent complete: 8.2%; Average loss: 3.9102
# Iteration: 327; Percent complete: 8.2%; Average loss: 3.8721
# Iteration: 328; Percent complete: 8.2%; Average loss: 3.6662
# Iteration: 329; Percent complete: 8.2%; Average loss: 3.8758
# Iteration: 330; Percent complete: 8.2%; Average loss: 3.7744
# Iteration: 331; Percent complete: 8.3%; Average loss: 3.7856
# Iteration: 332; Percent complete: 8.3%; Average loss: 3.9056
# Iteration: 333; Percent complete: 8.3%; Average loss: 3.9131
# Iteration: 334; Percent complete: 8.3%; Average loss: 4.1483
# Iteration: 335; Percent complete: 8.4%; Average loss: 4.2242
# Iteration: 336; Percent complete: 8.4%; Average loss: 3.9559
# Iteration: 337; Percent complete: 8.4%; Average loss: 3.7177
# Iteration: 338; Percent complete: 8.5%; Average loss: 3.7424
# Iteration: 339; Percent complete: 8.5%; Average loss: 3.8009
# Iteration: 340; Percent complete: 8.5%; Average loss: 3.7339
# Iteration: 341; Percent complete: 8.5%; Average loss: 3.7129
# Iteration: 342; Percent complete: 8.6%; Average loss: 3.6476
# Iteration: 343; Percent complete: 8.6%; Average loss: 3.9627
# Iteration: 344; Percent complete: 8.6%; Average loss: 3.9327
# Iteration: 345; Percent complete: 8.6%; Average loss: 4.0483
# Iteration: 346; Percent complete: 8.6%; Average loss: 3.8599
# Iteration: 347; Percent complete: 8.7%; Average loss: 3.9156
# Iteration: 348; Percent complete: 8.7%; Average loss: 3.8644
# Iteration: 349; Percent complete: 8.7%; Average loss: 3.9967
# Iteration: 350; Percent complete: 8.8%; Average loss: 4.0071
# Iteration: 351; Percent complete: 8.8%; Average loss: 3.9850
# Iteration: 352; Percent complete: 8.8%; Average loss: 3.8519
# Iteration: 353; Percent complete: 8.8%; Average loss: 3.7841
# Iteration: 354; Percent complete: 8.8%; Average loss: 3.6194
# Iteration: 355; Percent complete: 8.9%; Average loss: 3.9480
# Iteration: 356; Percent complete: 8.9%; Average loss: 3.8314
# Iteration: 357; Percent complete: 8.9%; Average loss: 3.5293
# Iteration: 358; Percent complete: 8.9%; Average loss: 3.8600
# Iteration: 359; Percent complete: 9.0%; Average loss: 3.9912
# Iteration: 360; Percent complete: 9.0%; Average loss: 4.1217
# Iteration: 361; Percent complete: 9.0%; Average loss: 3.4316
# Iteration: 362; Percent complete: 9.0%; Average loss: 3.8677
# Iteration: 363; Percent complete: 9.1%; Average loss: 3.7517
# Iteration: 364; Percent complete: 9.1%; Average loss: 4.0196
# Iteration: 365; Percent complete: 9.1%; Average loss: 3.8298
# Iteration: 366; Percent complete: 9.2%; Average loss: 4.0523
# Iteration: 367; Percent complete: 9.2%; Average loss: 3.8256
# Iteration: 368; Percent complete: 9.2%; Average loss: 3.7715
# Iteration: 369; Percent complete: 9.2%; Average loss: 3.8222
# Iteration: 370; Percent complete: 9.2%; Average loss: 3.7077
# Iteration: 371; Percent complete: 9.3%; Average loss: 3.8492
# Iteration: 372; Percent complete: 9.3%; Average loss: 4.1188
# Iteration: 373; Percent complete: 9.3%; Average loss: 3.9226
# Iteration: 374; Percent complete: 9.3%; Average loss: 3.7911
# Iteration: 375; Percent complete: 9.4%; Average loss: 3.8446
# Iteration: 376; Percent complete: 9.4%; Average loss: 3.8428
# Iteration: 377; Percent complete: 9.4%; Average loss: 3.9084
# Iteration: 378; Percent complete: 9.4%; Average loss: 3.7768
# Iteration: 379; Percent complete: 9.5%; Average loss: 3.7565
# Iteration: 380; Percent complete: 9.5%; Average loss: 3.8621
# Iteration: 381; Percent complete: 9.5%; Average loss: 3.8939
# Iteration: 382; Percent complete: 9.6%; Average loss: 3.7866
# Iteration: 383; Percent complete: 9.6%; Average loss: 3.8153
# Iteration: 384; Percent complete: 9.6%; Average loss: 3.9476
# Iteration: 385; Percent complete: 9.6%; Average loss: 3.7797
# Iteration: 386; Percent complete: 9.7%; Average loss: 3.7625
# Iteration: 387; Percent complete: 9.7%; Average loss: 3.9138
# Iteration: 388; Percent complete: 9.7%; Average loss: 4.1340
# Iteration: 389; Percent complete: 9.7%; Average loss: 3.8916
# Iteration: 390; Percent complete: 9.8%; Average loss: 3.7302
# Iteration: 391; Percent complete: 9.8%; Average loss: 3.9689
# Iteration: 392; Percent complete: 9.8%; Average loss: 3.7165
# Iteration: 393; Percent complete: 9.8%; Average loss: 3.8032
# Iteration: 394; Percent complete: 9.8%; Average loss: 3.9250
# Iteration: 395; Percent complete: 9.9%; Average loss: 3.7535
# Iteration: 396; Percent complete: 9.9%; Average loss: 4.1629
# Iteration: 397; Percent complete: 9.9%; Average loss: 3.5673
# Iteration: 398; Percent complete: 10.0%; Average loss: 3.7225
# Iteration: 399; Percent complete: 10.0%; Average loss: 3.7080
# Iteration: 400; Percent complete: 10.0%; Average loss: 4.3572
# Iteration: 401; Percent complete: 10.0%; Average loss: 3.6032
# Iteration: 402; Percent complete: 10.1%; Average loss: 3.6323
# Iteration: 403; Percent complete: 10.1%; Average loss: 3.7729
# Iteration: 404; Percent complete: 10.1%; Average loss: 3.6096
# Iteration: 405; Percent complete: 10.1%; Average loss: 4.0341
# Iteration: 406; Percent complete: 10.2%; Average loss: 3.9597
# Iteration: 407; Percent complete: 10.2%; Average loss: 3.8257
# Iteration: 408; Percent complete: 10.2%; Average loss: 3.9647
# Iteration: 409; Percent complete: 10.2%; Average loss: 3.6414
# Iteration: 410; Percent complete: 10.2%; Average loss: 3.6000
# Iteration: 411; Percent complete: 10.3%; Average loss: 3.6439
# Iteration: 412; Percent complete: 10.3%; Average loss: 3.8014
# Iteration: 413; Percent complete: 10.3%; Average loss: 3.7323
# Iteration: 414; Percent complete: 10.3%; Average loss: 4.0058
# Iteration: 415; Percent complete: 10.4%; Average loss: 3.6122
# Iteration: 416; Percent complete: 10.4%; Average loss: 3.7940
# Iteration: 417; Percent complete: 10.4%; Average loss: 4.0709
# Iteration: 418; Percent complete: 10.4%; Average loss: 3.5934
# Iteration: 419; Percent complete: 10.5%; Average loss: 3.7160
# Iteration: 420; Percent complete: 10.5%; Average loss: 3.7545
# Iteration: 421; Percent complete: 10.5%; Average loss: 4.1335
# Iteration: 422; Percent complete: 10.5%; Average loss: 3.6346
# Iteration: 423; Percent complete: 10.6%; Average loss: 3.6065
# Iteration: 424; Percent complete: 10.6%; Average loss: 4.0712
# Iteration: 425; Percent complete: 10.6%; Average loss: 3.6325
# Iteration: 426; Percent complete: 10.7%; Average loss: 3.9867
# Iteration: 427; Percent complete: 10.7%; Average loss: 3.7605
# Iteration: 428; Percent complete: 10.7%; Average loss: 3.6542
# Iteration: 429; Percent complete: 10.7%; Average loss: 3.7675
# Iteration: 430; Percent complete: 10.8%; Average loss: 4.0381
# Iteration: 431; Percent complete: 10.8%; Average loss: 3.7902
# Iteration: 432; Percent complete: 10.8%; Average loss: 3.7091
# Iteration: 433; Percent complete: 10.8%; Average loss: 3.7121
# Iteration: 434; Percent complete: 10.8%; Average loss: 3.7425
# Iteration: 435; Percent complete: 10.9%; Average loss: 3.9049
# Iteration: 436; Percent complete: 10.9%; Average loss: 3.7411
# Iteration: 437; Percent complete: 10.9%; Average loss: 3.7579
# Iteration: 438; Percent complete: 10.9%; Average loss: 4.0478
# Iteration: 439; Percent complete: 11.0%; Average loss: 3.7899
# Iteration: 440; Percent complete: 11.0%; Average loss: 3.9582
# Iteration: 441; Percent complete: 11.0%; Average loss: 3.7975
# Iteration: 442; Percent complete: 11.1%; Average loss: 3.8273
# Iteration: 443; Percent complete: 11.1%; Average loss: 3.5823
# Iteration: 444; Percent complete: 11.1%; Average loss: 3.5961
# Iteration: 445; Percent complete: 11.1%; Average loss: 3.5867
# Iteration: 446; Percent complete: 11.2%; Average loss: 3.8205
# Iteration: 447; Percent complete: 11.2%; Average loss: 3.5820
# Iteration: 448; Percent complete: 11.2%; Average loss: 4.0075
# Iteration: 449; Percent complete: 11.2%; Average loss: 4.0272
# Iteration: 450; Percent complete: 11.2%; Average loss: 3.7149
# Iteration: 451; Percent complete: 11.3%; Average loss: 3.7453
# Iteration: 452; Percent complete: 11.3%; Average loss: 3.7510
# Iteration: 453; Percent complete: 11.3%; Average loss: 3.8415
# Iteration: 454; Percent complete: 11.3%; Average loss: 3.9216
# Iteration: 455; Percent complete: 11.4%; Average loss: 3.6771
# Iteration: 456; Percent complete: 11.4%; Average loss: 3.7776
# Iteration: 457; Percent complete: 11.4%; Average loss: 3.7527
# Iteration: 458; Percent complete: 11.5%; Average loss: 3.7433
# Iteration: 459; Percent complete: 11.5%; Average loss: 3.5911
# Iteration: 460; Percent complete: 11.5%; Average loss: 3.6498
# Iteration: 461; Percent complete: 11.5%; Average loss: 3.8766
# Iteration: 462; Percent complete: 11.6%; Average loss: 3.6357
# Iteration: 463; Percent complete: 11.6%; Average loss: 4.1076
# Iteration: 464; Percent complete: 11.6%; Average loss: 4.0370
# Iteration: 465; Percent complete: 11.6%; Average loss: 3.7589
# Iteration: 466; Percent complete: 11.7%; Average loss: 3.7212
# Iteration: 467; Percent complete: 11.7%; Average loss: 3.7554
# Iteration: 468; Percent complete: 11.7%; Average loss: 3.7304
# Iteration: 469; Percent complete: 11.7%; Average loss: 3.4829
# Iteration: 470; Percent complete: 11.8%; Average loss: 3.8754
# Iteration: 471; Percent complete: 11.8%; Average loss: 3.7857
# Iteration: 472; Percent complete: 11.8%; Average loss: 3.5789
# Iteration: 473; Percent complete: 11.8%; Average loss: 3.8111
# Iteration: 474; Percent complete: 11.8%; Average loss: 3.4132
# Iteration: 475; Percent complete: 11.9%; Average loss: 3.7717
# Iteration: 476; Percent complete: 11.9%; Average loss: 3.5344
# Iteration: 477; Percent complete: 11.9%; Average loss: 3.6954
# Iteration: 478; Percent complete: 11.9%; Average loss: 3.6769
# Iteration: 479; Percent complete: 12.0%; Average loss: 3.9342
# Iteration: 480; Percent complete: 12.0%; Average loss: 3.9565
# Iteration: 481; Percent complete: 12.0%; Average loss: 3.6825
# Iteration: 482; Percent complete: 12.0%; Average loss: 3.5705
# Iteration: 483; Percent complete: 12.1%; Average loss: 3.9232
# Iteration: 484; Percent complete: 12.1%; Average loss: 3.9119
# Iteration: 485; Percent complete: 12.1%; Average loss: 3.5961
# Iteration: 486; Percent complete: 12.2%; Average loss: 3.9977
# Iteration: 487; Percent complete: 12.2%; Average loss: 3.5302
# Iteration: 488; Percent complete: 12.2%; Average loss: 3.6729
# Iteration: 489; Percent complete: 12.2%; Average loss: 3.9542
# Iteration: 490; Percent complete: 12.2%; Average loss: 3.7901
# Iteration: 491; Percent complete: 12.3%; Average loss: 3.8151
# Iteration: 492; Percent complete: 12.3%; Average loss: 3.7603
# Iteration: 493; Percent complete: 12.3%; Average loss: 3.6257
# Iteration: 494; Percent complete: 12.3%; Average loss: 3.7503
# Iteration: 495; Percent complete: 12.4%; Average loss: 3.8193
# Iteration: 496; Percent complete: 12.4%; Average loss: 3.8064
# Iteration: 497; Percent complete: 12.4%; Average loss: 3.7346
# Iteration: 498; Percent complete: 12.4%; Average loss: 3.5651
# Iteration: 499; Percent complete: 12.5%; Average loss: 3.6327
# Iteration: 500; Percent complete: 12.5%; Average loss: 3.8674
# Iteration: 501; Percent complete: 12.5%; Average loss: 3.6538
# Iteration: 502; Percent complete: 12.6%; Average loss: 3.4374
# Iteration: 503; Percent complete: 12.6%; Average loss: 3.7143
# Iteration: 504; Percent complete: 12.6%; Average loss: 3.7352
# Iteration: 505; Percent complete: 12.6%; Average loss: 3.8739
# Iteration: 506; Percent complete: 12.7%; Average loss: 3.6951
# Iteration: 507; Percent complete: 12.7%; Average loss: 3.9005
# Iteration: 508; Percent complete: 12.7%; Average loss: 3.8928
# Iteration: 509; Percent complete: 12.7%; Average loss: 3.5695
# Iteration: 510; Percent complete: 12.8%; Average loss: 3.6326
# Iteration: 511; Percent complete: 12.8%; Average loss: 3.8444
# Iteration: 512; Percent complete: 12.8%; Average loss: 3.7801
# Iteration: 513; Percent complete: 12.8%; Average loss: 3.9166
# Iteration: 514; Percent complete: 12.8%; Average loss: 3.7182
# Iteration: 515; Percent complete: 12.9%; Average loss: 3.8258
# Iteration: 516; Percent complete: 12.9%; Average loss: 3.9036
# Iteration: 517; Percent complete: 12.9%; Average loss: 3.8022
# Iteration: 518; Percent complete: 13.0%; Average loss: 3.8130
# Iteration: 519; Percent complete: 13.0%; Average loss: 3.7514
# Iteration: 520; Percent complete: 13.0%; Average loss: 3.6330
# Iteration: 521; Percent complete: 13.0%; Average loss: 3.7029
# Iteration: 522; Percent complete: 13.1%; Average loss: 3.5630
# Iteration: 523; Percent complete: 13.1%; Average loss: 3.8371
# Iteration: 524; Percent complete: 13.1%; Average loss: 3.7099
# Iteration: 525; Percent complete: 13.1%; Average loss: 3.6736
# Iteration: 526; Percent complete: 13.2%; Average loss: 3.5977
# Iteration: 527; Percent complete: 13.2%; Average loss: 3.3960
# Iteration: 528; Percent complete: 13.2%; Average loss: 3.8188
# Iteration: 529; Percent complete: 13.2%; Average loss: 3.8603
# Iteration: 530; Percent complete: 13.2%; Average loss: 3.4299
# Iteration: 531; Percent complete: 13.3%; Average loss: 3.6482
# Iteration: 532; Percent complete: 13.3%; Average loss: 3.7071
# Iteration: 533; Percent complete: 13.3%; Average loss: 3.4059
# Iteration: 534; Percent complete: 13.4%; Average loss: 3.8295
# Iteration: 535; Percent complete: 13.4%; Average loss: 3.5640
# Iteration: 536; Percent complete: 13.4%; Average loss: 3.6832
# Iteration: 537; Percent complete: 13.4%; Average loss: 3.6296
# Iteration: 538; Percent complete: 13.5%; Average loss: 3.9780
# Iteration: 539; Percent complete: 13.5%; Average loss: 3.6699
# Iteration: 540; Percent complete: 13.5%; Average loss: 3.4798
# Iteration: 541; Percent complete: 13.5%; Average loss: 3.8264
# Iteration: 542; Percent complete: 13.6%; Average loss: 3.5571
# Iteration: 543; Percent complete: 13.6%; Average loss: 3.4766
# Iteration: 544; Percent complete: 13.6%; Average loss: 3.5430
# Iteration: 545; Percent complete: 13.6%; Average loss: 3.5899
# Iteration: 546; Percent complete: 13.7%; Average loss: 3.3776
# Iteration: 547; Percent complete: 13.7%; Average loss: 3.5012
# Iteration: 548; Percent complete: 13.7%; Average loss: 3.6361
# Iteration: 549; Percent complete: 13.7%; Average loss: 3.6079
# Iteration: 550; Percent complete: 13.8%; Average loss: 4.1463
# Iteration: 551; Percent complete: 13.8%; Average loss: 3.8838
# Iteration: 552; Percent complete: 13.8%; Average loss: 3.9032
# Iteration: 553; Percent complete: 13.8%; Average loss: 3.7289
# Iteration: 554; Percent complete: 13.9%; Average loss: 3.6611
# Iteration: 555; Percent complete: 13.9%; Average loss: 3.6182
# Iteration: 556; Percent complete: 13.9%; Average loss: 3.6853
# Iteration: 557; Percent complete: 13.9%; Average loss: 3.9011
# Iteration: 558; Percent complete: 14.0%; Average loss: 3.6301
# Iteration: 559; Percent complete: 14.0%; Average loss: 3.9179
# Iteration: 560; Percent complete: 14.0%; Average loss: 3.8352
# Iteration: 561; Percent complete: 14.0%; Average loss: 3.9169
# Iteration: 562; Percent complete: 14.1%; Average loss: 3.4627
# Iteration: 563; Percent complete: 14.1%; Average loss: 3.7556
# Iteration: 564; Percent complete: 14.1%; Average loss: 3.8523
# Iteration: 565; Percent complete: 14.1%; Average loss: 3.6424
# Iteration: 566; Percent complete: 14.1%; Average loss: 3.6630
# Iteration: 567; Percent complete: 14.2%; Average loss: 3.7227
# Iteration: 568; Percent complete: 14.2%; Average loss: 3.7830
# Iteration: 569; Percent complete: 14.2%; Average loss: 3.9024
# Iteration: 570; Percent complete: 14.2%; Average loss: 3.5885
# Iteration: 571; Percent complete: 14.3%; Average loss: 3.5163
# Iteration: 572; Percent complete: 14.3%; Average loss: 3.6402
# Iteration: 573; Percent complete: 14.3%; Average loss: 3.8716
# Iteration: 574; Percent complete: 14.3%; Average loss: 3.8784
# Iteration: 575; Percent complete: 14.4%; Average loss: 3.6833
# Iteration: 576; Percent complete: 14.4%; Average loss: 3.7133
# Iteration: 577; Percent complete: 14.4%; Average loss: 3.5587
# Iteration: 578; Percent complete: 14.4%; Average loss: 3.9469
# Iteration: 579; Percent complete: 14.5%; Average loss: 3.8258
# Iteration: 580; Percent complete: 14.5%; Average loss: 3.9737
# Iteration: 581; Percent complete: 14.5%; Average loss: 3.6404
# Iteration: 582; Percent complete: 14.5%; Average loss: 3.7186
# Iteration: 583; Percent complete: 14.6%; Average loss: 3.6331
# Iteration: 584; Percent complete: 14.6%; Average loss: 3.6832
# Iteration: 585; Percent complete: 14.6%; Average loss: 3.7016
# Iteration: 586; Percent complete: 14.6%; Average loss: 3.7402
# Iteration: 587; Percent complete: 14.7%; Average loss: 3.7296
# Iteration: 588; Percent complete: 14.7%; Average loss: 3.8763
# Iteration: 589; Percent complete: 14.7%; Average loss: 3.7343
# Iteration: 590; Percent complete: 14.8%; Average loss: 3.7602
# Iteration: 591; Percent complete: 14.8%; Average loss: 3.8445
# Iteration: 592; Percent complete: 14.8%; Average loss: 3.8947
# Iteration: 593; Percent complete: 14.8%; Average loss: 3.7046
# Iteration: 594; Percent complete: 14.8%; Average loss: 3.6708
# Iteration: 595; Percent complete: 14.9%; Average loss: 3.8964
# Iteration: 596; Percent complete: 14.9%; Average loss: 3.6217
# Iteration: 597; Percent complete: 14.9%; Average loss: 3.5457
# Iteration: 598; Percent complete: 14.9%; Average loss: 3.3902
# Iteration: 599; Percent complete: 15.0%; Average loss: 3.9783
# Iteration: 600; Percent complete: 15.0%; Average loss: 3.3026
# Iteration: 601; Percent complete: 15.0%; Average loss: 3.6776
# Iteration: 602; Percent complete: 15.0%; Average loss: 3.5910
# Iteration: 603; Percent complete: 15.1%; Average loss: 3.5133
# Iteration: 604; Percent complete: 15.1%; Average loss: 3.4004
# Iteration: 605; Percent complete: 15.1%; Average loss: 3.4488
# Iteration: 606; Percent complete: 15.2%; Average loss: 3.7625
# Iteration: 607; Percent complete: 15.2%; Average loss: 3.5851
# Iteration: 608; Percent complete: 15.2%; Average loss: 3.7754
# Iteration: 609; Percent complete: 15.2%; Average loss: 3.7215
# Iteration: 610; Percent complete: 15.2%; Average loss: 3.9084
# Iteration: 611; Percent complete: 15.3%; Average loss: 3.3925
# Iteration: 612; Percent complete: 15.3%; Average loss: 3.5927
# Iteration: 613; Percent complete: 15.3%; Average loss: 3.5612
# Iteration: 614; Percent complete: 15.3%; Average loss: 3.5965
# Iteration: 615; Percent complete: 15.4%; Average loss: 3.5651
# Iteration: 616; Percent complete: 15.4%; Average loss: 3.6278
# Iteration: 617; Percent complete: 15.4%; Average loss: 3.5722
# Iteration: 618; Percent complete: 15.4%; Average loss: 3.6308
# Iteration: 619; Percent complete: 15.5%; Average loss: 3.5507
# Iteration: 620; Percent complete: 15.5%; Average loss: 3.5157
# Iteration: 621; Percent complete: 15.5%; Average loss: 3.4890
# Iteration: 622; Percent complete: 15.6%; Average loss: 3.8578
# Iteration: 623; Percent complete: 15.6%; Average loss: 3.9090
# Iteration: 624; Percent complete: 15.6%; Average loss: 3.5493
# Iteration: 625; Percent complete: 15.6%; Average loss: 3.6793
# Iteration: 626; Percent complete: 15.7%; Average loss: 3.4383
# Iteration: 627; Percent complete: 15.7%; Average loss: 3.6097
# Iteration: 628; Percent complete: 15.7%; Average loss: 3.4367
# Iteration: 629; Percent complete: 15.7%; Average loss: 3.7043
# Iteration: 630; Percent complete: 15.8%; Average loss: 3.6586
# Iteration: 631; Percent complete: 15.8%; Average loss: 3.6489
# Iteration: 632; Percent complete: 15.8%; Average loss: 3.4643
# Iteration: 633; Percent complete: 15.8%; Average loss: 3.8564
# Iteration: 634; Percent complete: 15.8%; Average loss: 3.5874
# Iteration: 635; Percent complete: 15.9%; Average loss: 3.7428
# Iteration: 636; Percent complete: 15.9%; Average loss: 3.6388
# Iteration: 637; Percent complete: 15.9%; Average loss: 3.6438
# Iteration: 638; Percent complete: 16.0%; Average loss: 3.4523
# Iteration: 639; Percent complete: 16.0%; Average loss: 3.5924
# Iteration: 640; Percent complete: 16.0%; Average loss: 3.6956
# Iteration: 641; Percent complete: 16.0%; Average loss: 3.5607
# Iteration: 642; Percent complete: 16.1%; Average loss: 3.7666
# Iteration: 643; Percent complete: 16.1%; Average loss: 3.6434
# Iteration: 644; Percent complete: 16.1%; Average loss: 3.6448
# Iteration: 645; Percent complete: 16.1%; Average loss: 3.7977
# Iteration: 646; Percent complete: 16.2%; Average loss: 3.9400
# Iteration: 647; Percent complete: 16.2%; Average loss: 3.7735
# Iteration: 648; Percent complete: 16.2%; Average loss: 3.6826
# Iteration: 649; Percent complete: 16.2%; Average loss: 3.5649
# Iteration: 650; Percent complete: 16.2%; Average loss: 3.5684
# Iteration: 651; Percent complete: 16.3%; Average loss: 3.3541
# Iteration: 652; Percent complete: 16.3%; Average loss: 3.6508
# Iteration: 653; Percent complete: 16.3%; Average loss: 3.6015
# Iteration: 654; Percent complete: 16.4%; Average loss: 3.5699
# Iteration: 655; Percent complete: 16.4%; Average loss: 3.7985
# Iteration: 656; Percent complete: 16.4%; Average loss: 3.6463
# Iteration: 657; Percent complete: 16.4%; Average loss: 3.8527
# Iteration: 658; Percent complete: 16.4%; Average loss: 3.6987
# Iteration: 659; Percent complete: 16.5%; Average loss: 3.7204
# Iteration: 660; Percent complete: 16.5%; Average loss: 3.5118
# Iteration: 661; Percent complete: 16.5%; Average loss: 3.8310
# Iteration: 662; Percent complete: 16.6%; Average loss: 3.6853
# Iteration: 663; Percent complete: 16.6%; Average loss: 3.7544
# Iteration: 664; Percent complete: 16.6%; Average loss: 3.3484
# Iteration: 665; Percent complete: 16.6%; Average loss: 3.4331
# Iteration: 666; Percent complete: 16.7%; Average loss: 3.4097
# Iteration: 667; Percent complete: 16.7%; Average loss: 3.7117
# Iteration: 668; Percent complete: 16.7%; Average loss: 3.6594
# Iteration: 669; Percent complete: 16.7%; Average loss: 4.0307
# Iteration: 670; Percent complete: 16.8%; Average loss: 3.6132
# Iteration: 671; Percent complete: 16.8%; Average loss: 3.4916
# Iteration: 672; Percent complete: 16.8%; Average loss: 3.3881
# Iteration: 673; Percent complete: 16.8%; Average loss: 3.6629
# Iteration: 674; Percent complete: 16.9%; Average loss: 3.5314
# Iteration: 675; Percent complete: 16.9%; Average loss: 3.7185
# Iteration: 676; Percent complete: 16.9%; Average loss: 3.6194
# Iteration: 677; Percent complete: 16.9%; Average loss: 3.6028
# Iteration: 678; Percent complete: 17.0%; Average loss: 3.5507
# Iteration: 679; Percent complete: 17.0%; Average loss: 3.4215
# Iteration: 680; Percent complete: 17.0%; Average loss: 3.4417
# Iteration: 681; Percent complete: 17.0%; Average loss: 3.5498
# Iteration: 682; Percent complete: 17.1%; Average loss: 3.7366
# Iteration: 683; Percent complete: 17.1%; Average loss: 3.8674
# Iteration: 684; Percent complete: 17.1%; Average loss: 3.5084
# Iteration: 685; Percent complete: 17.1%; Average loss: 3.6713
# Iteration: 686; Percent complete: 17.2%; Average loss: 3.4304
# Iteration: 687; Percent complete: 17.2%; Average loss: 3.6975
# Iteration: 688; Percent complete: 17.2%; Average loss: 3.5548
# Iteration: 689; Percent complete: 17.2%; Average loss: 3.9023
# Iteration: 690; Percent complete: 17.2%; Average loss: 3.6585
# Iteration: 691; Percent complete: 17.3%; Average loss: 3.5510
# Iteration: 692; Percent complete: 17.3%; Average loss: 3.8647
# Iteration: 693; Percent complete: 17.3%; Average loss: 3.3393
# Iteration: 694; Percent complete: 17.3%; Average loss: 3.5614
# Iteration: 695; Percent complete: 17.4%; Average loss: 3.7832
# Iteration: 696; Percent complete: 17.4%; Average loss: 3.6935
# Iteration: 697; Percent complete: 17.4%; Average loss: 3.7029
# Iteration: 698; Percent complete: 17.4%; Average loss: 3.6010
# Iteration: 699; Percent complete: 17.5%; Average loss: 3.5916
# Iteration: 700; Percent complete: 17.5%; Average loss: 3.9114
# Iteration: 701; Percent complete: 17.5%; Average loss: 3.7331
# Iteration: 702; Percent complete: 17.5%; Average loss: 3.8023
# Iteration: 703; Percent complete: 17.6%; Average loss: 3.5272
# Iteration: 704; Percent complete: 17.6%; Average loss: 3.6102
# Iteration: 705; Percent complete: 17.6%; Average loss: 3.5818
# Iteration: 706; Percent complete: 17.6%; Average loss: 3.6179
# Iteration: 707; Percent complete: 17.7%; Average loss: 3.6336
# Iteration: 708; Percent complete: 17.7%; Average loss: 3.5591
# Iteration: 709; Percent complete: 17.7%; Average loss: 3.5628
# Iteration: 710; Percent complete: 17.8%; Average loss: 3.6646
# Iteration: 711; Percent complete: 17.8%; Average loss: 3.4217
# Iteration: 712; Percent complete: 17.8%; Average loss: 3.6175
# Iteration: 713; Percent complete: 17.8%; Average loss: 3.7037
# Iteration: 714; Percent complete: 17.8%; Average loss: 3.4939
# Iteration: 715; Percent complete: 17.9%; Average loss: 3.3923
# Iteration: 716; Percent complete: 17.9%; Average loss: 3.6120
# Iteration: 717; Percent complete: 17.9%; Average loss: 3.7867
# Iteration: 718; Percent complete: 17.9%; Average loss: 3.6386
# Iteration: 719; Percent complete: 18.0%; Average loss: 3.7457
# Iteration: 720; Percent complete: 18.0%; Average loss: 3.4499
# Iteration: 721; Percent complete: 18.0%; Average loss: 3.7361
# Iteration: 722; Percent complete: 18.1%; Average loss: 3.6452
# Iteration: 723; Percent complete: 18.1%; Average loss: 3.3746
# Iteration: 724; Percent complete: 18.1%; Average loss: 3.4298
# Iteration: 725; Percent complete: 18.1%; Average loss: 3.4760
# Iteration: 726; Percent complete: 18.1%; Average loss: 3.5426
# Iteration: 727; Percent complete: 18.2%; Average loss: 3.2408
# Iteration: 728; Percent complete: 18.2%; Average loss: 3.3343
# Iteration: 729; Percent complete: 18.2%; Average loss: 3.5600
# Iteration: 730; Percent complete: 18.2%; Average loss: 3.7341
# Iteration: 731; Percent complete: 18.3%; Average loss: 3.2402
# Iteration: 732; Percent complete: 18.3%; Average loss: 3.8253
# Iteration: 733; Percent complete: 18.3%; Average loss: 3.5106
# Iteration: 734; Percent complete: 18.4%; Average loss: 3.6489
# Iteration: 735; Percent complete: 18.4%; Average loss: 3.7521
# Iteration: 736; Percent complete: 18.4%; Average loss: 3.5243
# Iteration: 737; Percent complete: 18.4%; Average loss: 3.6096
# Iteration: 738; Percent complete: 18.4%; Average loss: 3.6475
# Iteration: 739; Percent complete: 18.5%; Average loss: 3.4195
# Iteration: 740; Percent complete: 18.5%; Average loss: 3.3625
# Iteration: 741; Percent complete: 18.5%; Average loss: 3.3341
# Iteration: 742; Percent complete: 18.6%; Average loss: 3.8013
# Iteration: 743; Percent complete: 18.6%; Average loss: 3.3284
# Iteration: 744; Percent complete: 18.6%; Average loss: 3.5263
# Iteration: 745; Percent complete: 18.6%; Average loss: 3.6938
# Iteration: 746; Percent complete: 18.6%; Average loss: 3.6046
# Iteration: 747; Percent complete: 18.7%; Average loss: 3.5223
# Iteration: 748; Percent complete: 18.7%; Average loss: 3.3641
# Iteration: 749; Percent complete: 18.7%; Average loss: 3.6667
# Iteration: 750; Percent complete: 18.8%; Average loss: 3.4569
# Iteration: 751; Percent complete: 18.8%; Average loss: 3.6664
# Iteration: 752; Percent complete: 18.8%; Average loss: 3.7033
# Iteration: 753; Percent complete: 18.8%; Average loss: 3.4376
# Iteration: 754; Percent complete: 18.9%; Average loss: 3.6132
# Iteration: 755; Percent complete: 18.9%; Average loss: 3.6042
# Iteration: 756; Percent complete: 18.9%; Average loss: 3.7007
# Iteration: 757; Percent complete: 18.9%; Average loss: 3.6557
# Iteration: 758; Percent complete: 18.9%; Average loss: 3.4877
# Iteration: 759; Percent complete: 19.0%; Average loss: 3.6997
# Iteration: 760; Percent complete: 19.0%; Average loss: 3.4261
# Iteration: 761; Percent complete: 19.0%; Average loss: 3.5562
# Iteration: 762; Percent complete: 19.1%; Average loss: 3.5951
# Iteration: 763; Percent complete: 19.1%; Average loss: 3.7808
# Iteration: 764; Percent complete: 19.1%; Average loss: 3.6553
# Iteration: 765; Percent complete: 19.1%; Average loss: 3.6805
# Iteration: 766; Percent complete: 19.1%; Average loss: 3.6106
# Iteration: 767; Percent complete: 19.2%; Average loss: 3.5554
# Iteration: 768; Percent complete: 19.2%; Average loss: 3.4378
# Iteration: 769; Percent complete: 19.2%; Average loss: 3.7148
# Iteration: 770; Percent complete: 19.2%; Average loss: 3.7038
# Iteration: 771; Percent complete: 19.3%; Average loss: 3.5513
# Iteration: 772; Percent complete: 19.3%; Average loss: 3.6599
# Iteration: 773; Percent complete: 19.3%; Average loss: 3.5938
# Iteration: 774; Percent complete: 19.4%; Average loss: 3.6044
# Iteration: 775; Percent complete: 19.4%; Average loss: 3.6221
# Iteration: 776; Percent complete: 19.4%; Average loss: 3.7573
# Iteration: 777; Percent complete: 19.4%; Average loss: 3.5301
# Iteration: 778; Percent complete: 19.4%; Average loss: 3.4742
# Iteration: 779; Percent complete: 19.5%; Average loss: 3.4152
# Iteration: 780; Percent complete: 19.5%; Average loss: 3.5626
# Iteration: 781; Percent complete: 19.5%; Average loss: 3.6189
# ...
# Iteration: 3748; Percent complete: 93.7%; Average loss: 2.6293
# Iteration: 3749; Percent complete: 93.7%; Average loss: 2.7349
# Iteration: 3750; Percent complete: 93.8%; Average loss: 2.7259
# Iteration: 3751; Percent complete: 93.8%; Average loss: 2.7978
# Iteration: 3752; Percent complete: 93.8%; Average loss: 2.7900
# Iteration: 3753; Percent complete: 93.8%; Average loss: 2.4939
# Iteration: 3754; Percent complete: 93.8%; Average loss: 2.4899
# Iteration: 3755; Percent complete: 93.9%; Average loss: 2.8003
# Iteration: 3756; Percent complete: 93.9%; Average loss: 2.8331
# Iteration: 3757; Percent complete: 93.9%; Average loss: 2.6859
# Iteration: 3758; Percent complete: 94.0%; Average loss: 2.6471
# Iteration: 3759; Percent complete: 94.0%; Average loss: 2.8191
# Iteration: 3760; Percent complete: 94.0%; Average loss: 2.7833
# Iteration: 3761; Percent complete: 94.0%; Average loss: 2.7261
# Iteration: 3762; Percent complete: 94.0%; Average loss: 2.7574
# Iteration: 3763; Percent complete: 94.1%; Average loss: 2.6413
# Iteration: 3764; Percent complete: 94.1%; Average loss: 2.6163
# Iteration: 3765; Percent complete: 94.1%; Average loss: 2.4354
# Iteration: 3766; Percent complete: 94.2%; Average loss: 2.4711
# Iteration: 3767; Percent complete: 94.2%; Average loss: 2.6447
# Iteration: 3768; Percent complete: 94.2%; Average loss: 2.8157
# Iteration: 3769; Percent complete: 94.2%; Average loss: 2.7013
# Iteration: 3770; Percent complete: 94.2%; Average loss: 2.4744
# Iteration: 3771; Percent complete: 94.3%; Average loss: 2.7181
# Iteration: 3772; Percent complete: 94.3%; Average loss: 2.6512
# Iteration: 3773; Percent complete: 94.3%; Average loss: 2.5055
# Iteration: 3774; Percent complete: 94.3%; Average loss: 2.5225
# Iteration: 3775; Percent complete: 94.4%; Average loss: 2.6097
# Iteration: 3776; Percent complete: 94.4%; Average loss: 2.5497
# Iteration: 3777; Percent complete: 94.4%; Average loss: 2.6273
# Iteration: 3778; Percent complete: 94.5%; Average loss: 2.5997
# Iteration: 3779; Percent complete: 94.5%; Average loss: 2.7174
# Iteration: 3780; Percent complete: 94.5%; Average loss: 2.9291
# Iteration: 3781; Percent complete: 94.5%; Average loss: 2.8313
# Iteration: 3782; Percent complete: 94.5%; Average loss: 2.5745
# Iteration: 3783; Percent complete: 94.6%; Average loss: 2.8518
# Iteration: 3784; Percent complete: 94.6%; Average loss: 2.6056
# Iteration: 3785; Percent complete: 94.6%; Average loss: 2.6052
# Iteration: 3786; Percent complete: 94.7%; Average loss: 2.8665
# Iteration: 3787; Percent complete: 94.7%; Average loss: 2.7195
# Iteration: 3788; Percent complete: 94.7%; Average loss: 2.7793
# Iteration: 3789; Percent complete: 94.7%; Average loss: 2.3866
# Iteration: 3790; Percent complete: 94.8%; Average loss: 2.7632
# Iteration: 3791; Percent complete: 94.8%; Average loss: 2.5960
# Iteration: 3792; Percent complete: 94.8%; Average loss: 2.6560
# Iteration: 3793; Percent complete: 94.8%; Average loss: 2.7023
# Iteration: 3794; Percent complete: 94.8%; Average loss: 2.9304
# Iteration: 3795; Percent complete: 94.9%; Average loss: 2.5180
# Iteration: 3796; Percent complete: 94.9%; Average loss: 2.9441
# Iteration: 3797; Percent complete: 94.9%; Average loss: 2.8830
# Iteration: 3798; Percent complete: 95.0%; Average loss: 2.8300
# Iteration: 3799; Percent complete: 95.0%; Average loss: 2.7556
# Iteration: 3800; Percent complete: 95.0%; Average loss: 2.4689
# Iteration: 3801; Percent complete: 95.0%; Average loss: 2.7369
# Iteration: 3802; Percent complete: 95.0%; Average loss: 2.8032
# Iteration: 3803; Percent complete: 95.1%; Average loss: 2.7915
# Iteration: 3804; Percent complete: 95.1%; Average loss: 2.5993
# Iteration: 3805; Percent complete: 95.1%; Average loss: 2.6082
# Iteration: 3806; Percent complete: 95.2%; Average loss: 2.6166
# Iteration: 3807; Percent complete: 95.2%; Average loss: 2.7933
# Iteration: 3808; Percent complete: 95.2%; Average loss: 2.5474
# Iteration: 3809; Percent complete: 95.2%; Average loss: 2.4512
# Iteration: 3810; Percent complete: 95.2%; Average loss: 2.5921
# Iteration: 3811; Percent complete: 95.3%; Average loss: 2.5460
# Iteration: 3812; Percent complete: 95.3%; Average loss: 2.4029
# Iteration: 3813; Percent complete: 95.3%; Average loss: 2.5525
# Iteration: 3814; Percent complete: 95.3%; Average loss: 2.8264
# Iteration: 3815; Percent complete: 95.4%; Average loss: 2.8355
# Iteration: 3816; Percent complete: 95.4%; Average loss: 2.5340
# Iteration: 3817; Percent complete: 95.4%; Average loss: 2.6797
# Iteration: 3818; Percent complete: 95.5%; Average loss: 2.6344
# Iteration: 3819; Percent complete: 95.5%; Average loss: 2.8086
# Iteration: 3820; Percent complete: 95.5%; Average loss: 2.7204
# Iteration: 3821; Percent complete: 95.5%; Average loss: 2.7106
# Iteration: 3822; Percent complete: 95.5%; Average loss: 2.5119
# Iteration: 3823; Percent complete: 95.6%; Average loss: 2.8189
# Iteration: 3824; Percent complete: 95.6%; Average loss: 2.8579
# Iteration: 3825; Percent complete: 95.6%; Average loss: 2.6657
# Iteration: 3826; Percent complete: 95.7%; Average loss: 2.7598
# Iteration: 3827; Percent complete: 95.7%; Average loss: 2.7428
# Iteration: 3828; Percent complete: 95.7%; Average loss: 2.3514
# Iteration: 3829; Percent complete: 95.7%; Average loss: 2.4172
# Iteration: 3830; Percent complete: 95.8%; Average loss: 2.6946
# Iteration: 3831; Percent complete: 95.8%; Average loss: 2.6062
# Iteration: 3832; Percent complete: 95.8%; Average loss: 2.6756
# Iteration: 3833; Percent complete: 95.8%; Average loss: 2.6406
# Iteration: 3834; Percent complete: 95.9%; Average loss: 2.7525
# Iteration: 3835; Percent complete: 95.9%; Average loss: 2.5873
# Iteration: 3836; Percent complete: 95.9%; Average loss: 2.5020
# Iteration: 3837; Percent complete: 95.9%; Average loss: 2.7529
# Iteration: 3838; Percent complete: 96.0%; Average loss: 2.6843
# Iteration: 3839; Percent complete: 96.0%; Average loss: 2.4889
# Iteration: 3840; Percent complete: 96.0%; Average loss: 2.8526
# Iteration: 3841; Percent complete: 96.0%; Average loss: 2.8512
# Iteration: 3842; Percent complete: 96.0%; Average loss: 2.6919
# Iteration: 3843; Percent complete: 96.1%; Average loss: 2.5441
# Iteration: 3844; Percent complete: 96.1%; Average loss: 2.6487
# Iteration: 3845; Percent complete: 96.1%; Average loss: 2.4914
# Iteration: 3846; Percent complete: 96.2%; Average loss: 2.6980
# Iteration: 3847; Percent complete: 96.2%; Average loss: 2.6042
# Iteration: 3848; Percent complete: 96.2%; Average loss: 2.7110
# Iteration: 3849; Percent complete: 96.2%; Average loss: 2.8048
# Iteration: 3850; Percent complete: 96.2%; Average loss: 2.7233
# Iteration: 3851; Percent complete: 96.3%; Average loss: 2.3723
# Iteration: 3852; Percent complete: 96.3%; Average loss: 2.8376
# Iteration: 3853; Percent complete: 96.3%; Average loss: 2.4975
# Iteration: 3854; Percent complete: 96.4%; Average loss: 2.5119
# Iteration: 3855; Percent complete: 96.4%; Average loss: 2.7801
# Iteration: 3856; Percent complete: 96.4%; Average loss: 2.6744
# Iteration: 3857; Percent complete: 96.4%; Average loss: 2.4658
# Iteration: 3858; Percent complete: 96.5%; Average loss: 2.6762
# Iteration: 3859; Percent complete: 96.5%; Average loss: 2.7539
# Iteration: 3860; Percent complete: 96.5%; Average loss: 2.6900
# Iteration: 3861; Percent complete: 96.5%; Average loss: 2.7627
# Iteration: 3862; Percent complete: 96.5%; Average loss: 2.9800
# Iteration: 3863; Percent complete: 96.6%; Average loss: 2.6050
# Iteration: 3864; Percent complete: 96.6%; Average loss: 2.6194
# Iteration: 3865; Percent complete: 96.6%; Average loss: 2.6635
# Iteration: 3866; Percent complete: 96.7%; Average loss: 2.5212
# Iteration: 3867; Percent complete: 96.7%; Average loss: 2.6725
# Iteration: 3868; Percent complete: 96.7%; Average loss: 2.8122
# Iteration: 3869; Percent complete: 96.7%; Average loss: 2.6323
# Iteration: 3870; Percent complete: 96.8%; Average loss: 2.6890
# Iteration: 3871; Percent complete: 96.8%; Average loss: 2.5659
# Iteration: 3872; Percent complete: 96.8%; Average loss: 2.6440
# Iteration: 3873; Percent complete: 96.8%; Average loss: 2.5287
# Iteration: 3874; Percent complete: 96.9%; Average loss: 2.4167
# Iteration: 3875; Percent complete: 96.9%; Average loss: 2.4482
# Iteration: 3876; Percent complete: 96.9%; Average loss: 2.7311
# Iteration: 3877; Percent complete: 96.9%; Average loss: 2.5454
# Iteration: 3878; Percent complete: 97.0%; Average loss: 2.5227
# Iteration: 3879; Percent complete: 97.0%; Average loss: 2.5455
# Iteration: 3880; Percent complete: 97.0%; Average loss: 2.3416
# Iteration: 3881; Percent complete: 97.0%; Average loss: 2.7723
# Iteration: 3882; Percent complete: 97.0%; Average loss: 2.7373
# Iteration: 3883; Percent complete: 97.1%; Average loss: 2.6585
# Iteration: 3884; Percent complete: 97.1%; Average loss: 2.5541
# Iteration: 3885; Percent complete: 97.1%; Average loss: 2.6283
# Iteration: 3886; Percent complete: 97.2%; Average loss: 2.6614
# Iteration: 3887; Percent complete: 97.2%; Average loss: 2.6499
# Iteration: 3888; Percent complete: 97.2%; Average loss: 2.7758
# Iteration: 3889; Percent complete: 97.2%; Average loss: 2.8086
# Iteration: 3890; Percent complete: 97.2%; Average loss: 2.5867
# Iteration: 3891; Percent complete: 97.3%; Average loss: 2.5573
# Iteration: 3892; Percent complete: 97.3%; Average loss: 2.7640
# Iteration: 3893; Percent complete: 97.3%; Average loss: 2.6658
# Iteration: 3894; Percent complete: 97.4%; Average loss: 2.6774
# Iteration: 3895; Percent complete: 97.4%; Average loss: 2.6276
# Iteration: 3896; Percent complete: 97.4%; Average loss: 2.6279
# Iteration: 3897; Percent complete: 97.4%; Average loss: 2.7655
# Iteration: 3898; Percent complete: 97.5%; Average loss: 2.9019
# Iteration: 3899; Percent complete: 97.5%; Average loss: 2.6189
# Iteration: 3900; Percent complete: 97.5%; Average loss: 2.7341
# Iteration: 3901; Percent complete: 97.5%; Average loss: 2.8148
# Iteration: 3902; Percent complete: 97.5%; Average loss: 2.5801
# Iteration: 3903; Percent complete: 97.6%; Average loss: 2.7919
# Iteration: 3904; Percent complete: 97.6%; Average loss: 2.7674
# Iteration: 3905; Percent complete: 97.6%; Average loss: 2.7618
# Iteration: 3906; Percent complete: 97.7%; Average loss: 2.6224
# Iteration: 3907; Percent complete: 97.7%; Average loss: 2.6589
# Iteration: 3908; Percent complete: 97.7%; Average loss: 2.5384
# Iteration: 3909; Percent complete: 97.7%; Average loss: 2.6849
# Iteration: 3910; Percent complete: 97.8%; Average loss: 2.2540
# Iteration: 3911; Percent complete: 97.8%; Average loss: 2.5153
# Iteration: 3912; Percent complete: 97.8%; Average loss: 2.7575
# Iteration: 3913; Percent complete: 97.8%; Average loss: 2.6282
# Iteration: 3914; Percent complete: 97.9%; Average loss: 2.5954
# Iteration: 3915; Percent complete: 97.9%; Average loss: 2.7572
# Iteration: 3916; Percent complete: 97.9%; Average loss: 2.5692
# Iteration: 3917; Percent complete: 97.9%; Average loss: 2.5273
# Iteration: 3918; Percent complete: 98.0%; Average loss: 2.6551
# Iteration: 3919; Percent complete: 98.0%; Average loss: 2.6365
# Iteration: 3920; Percent complete: 98.0%; Average loss: 2.7564
# Iteration: 3921; Percent complete: 98.0%; Average loss: 2.7540
# Iteration: 3922; Percent complete: 98.0%; Average loss: 2.6350
# Iteration: 3923; Percent complete: 98.1%; Average loss: 2.4108
# Iteration: 3924; Percent complete: 98.1%; Average loss: 2.5532
# Iteration: 3925; Percent complete: 98.1%; Average loss: 2.5804
# Iteration: 3926; Percent complete: 98.2%; Average loss: 2.6497
# Iteration: 3927; Percent complete: 98.2%; Average loss: 2.4901
# Iteration: 3928; Percent complete: 98.2%; Average loss: 2.6423
# Iteration: 3929; Percent complete: 98.2%; Average loss: 2.5951
# Iteration: 3930; Percent complete: 98.2%; Average loss: 2.4155
# Iteration: 3931; Percent complete: 98.3%; Average loss: 2.6057
# Iteration: 3932; Percent complete: 98.3%; Average loss: 2.6035
# Iteration: 3933; Percent complete: 98.3%; Average loss: 2.7586
# Iteration: 3934; Percent complete: 98.4%; Average loss: 2.4352
# Iteration: 3935; Percent complete: 98.4%; Average loss: 2.6269
# Iteration: 3936; Percent complete: 98.4%; Average loss: 2.7814
# Iteration: 3937; Percent complete: 98.4%; Average loss: 2.4707
# Iteration: 3938; Percent complete: 98.5%; Average loss: 2.8092
# Iteration: 3939; Percent complete: 98.5%; Average loss: 2.5923
# Iteration: 3940; Percent complete: 98.5%; Average loss: 2.6570
# Iteration: 3941; Percent complete: 98.5%; Average loss: 2.7596
# Iteration: 3942; Percent complete: 98.6%; Average loss: 2.6276
# Iteration: 3943; Percent complete: 98.6%; Average loss: 2.7636
# Iteration: 3944; Percent complete: 98.6%; Average loss: 2.4990
# Iteration: 3945; Percent complete: 98.6%; Average loss: 2.8566
# Iteration: 3946; Percent complete: 98.7%; Average loss: 2.7783
# Iteration: 3947; Percent complete: 98.7%; Average loss: 2.6051
# Iteration: 3948; Percent complete: 98.7%; Average loss: 2.5414
# Iteration: 3949; Percent complete: 98.7%; Average loss: 2.8882
# Iteration: 3950; Percent complete: 98.8%; Average loss: 2.5618
# Iteration: 3951; Percent complete: 98.8%; Average loss: 2.6654
# Iteration: 3952; Percent complete: 98.8%; Average loss: 2.5690
# Iteration: 3953; Percent complete: 98.8%; Average loss: 2.6277
# Iteration: 3954; Percent complete: 98.9%; Average loss: 2.4930
# Iteration: 3955; Percent complete: 98.9%; Average loss: 2.6171
# Iteration: 3956; Percent complete: 98.9%; Average loss: 2.4862
# Iteration: 3957; Percent complete: 98.9%; Average loss: 2.4983
# Iteration: 3958; Percent complete: 99.0%; Average loss: 2.7641
# Iteration: 3959; Percent complete: 99.0%; Average loss: 2.4073
# Iteration: 3960; Percent complete: 99.0%; Average loss: 2.6556
# Iteration: 3961; Percent complete: 99.0%; Average loss: 2.3701
# Iteration: 3962; Percent complete: 99.1%; Average loss: 2.6474
# Iteration: 3963; Percent complete: 99.1%; Average loss: 2.5462
# Iteration: 3964; Percent complete: 99.1%; Average loss: 2.5463
# Iteration: 3965; Percent complete: 99.1%; Average loss: 2.3859
# Iteration: 3966; Percent complete: 99.2%; Average loss: 2.4798
# Iteration: 3967; Percent complete: 99.2%; Average loss: 2.4790
# Iteration: 3968; Percent complete: 99.2%; Average loss: 2.4798
# Iteration: 3969; Percent complete: 99.2%; Average loss: 2.3285
# Iteration: 3970; Percent complete: 99.2%; Average loss: 2.6426
# Iteration: 3971; Percent complete: 99.3%; Average loss: 2.5438
# Iteration: 3972; Percent complete: 99.3%; Average loss: 2.4228
# Iteration: 3973; Percent complete: 99.3%; Average loss: 2.5893
# Iteration: 3974; Percent complete: 99.4%; Average loss: 2.3984
# Iteration: 3975; Percent complete: 99.4%; Average loss: 2.6548
# Iteration: 3976; Percent complete: 99.4%; Average loss: 2.4527
# Iteration: 3977; Percent complete: 99.4%; Average loss: 2.7328
# Iteration: 3978; Percent complete: 99.5%; Average loss: 2.5452
# Iteration: 3979; Percent complete: 99.5%; Average loss: 2.6646
# Iteration: 3980; Percent complete: 99.5%; Average loss: 2.5852
# Iteration: 3981; Percent complete: 99.5%; Average loss: 2.8084
# Iteration: 3982; Percent complete: 99.6%; Average loss: 2.6706
# Iteration: 3983; Percent complete: 99.6%; Average loss: 2.7295
# Iteration: 3984; Percent complete: 99.6%; Average loss: 2.7225
# Iteration: 3985; Percent complete: 99.6%; Average loss: 2.5926
# Iteration: 3986; Percent complete: 99.7%; Average loss: 2.6199
# Iteration: 3987; Percent complete: 99.7%; Average loss: 2.7567
# Iteration: 3988; Percent complete: 99.7%; Average loss: 2.5752
# Iteration: 3989; Percent complete: 99.7%; Average loss: 2.8430
# Iteration: 3990; Percent complete: 99.8%; Average loss: 2.8321
# Iteration: 3991; Percent complete: 99.8%; Average loss: 2.6943
# Iteration: 3992; Percent complete: 99.8%; Average loss: 2.5347
# Iteration: 3993; Percent complete: 99.8%; Average loss: 2.6986
# Iteration: 3994; Percent complete: 99.9%; Average loss: 2.5396
# Iteration: 3995; Percent complete: 99.9%; Average loss: 2.6929
# Iteration: 3996; Percent complete: 99.9%; Average loss: 2.3777
# Iteration: 3997; Percent complete: 99.9%; Average loss: 2.7159
# Iteration: 3998; Percent complete: 100.0%; Average loss: 2.6589
# Iteration: 3999; Percent complete: 100.0%; Average loss: 2.4809
# Iteration: 4000; Percent complete: 100.0%; Average loss: 2.3980

# %% [markdown]
# #### Run Evaluation
#
# To chat with your model, run the following block.

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting by uncommenting the line:
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > hello
# Bot: hello . . . . .
# > how are you
# Bot: i m not okay . . .
# > why not?
# Bot: i don t know . . .
# > why don't you know?
# Bot: i don t know . . .
# > okay
# Bot: okay . i m okay . .
# > how old are you?
# Bot: i m not . . . .
# > not what?
# Bot: i m not . . . .
# > play a game
# Bot: you re a good girl . . .
# > im not a girl
# Bot: you re a girl . . .
# > you have no gender
# Bot: no . i m not . .
# > im a boy
# Bot: a girl was a gift . . .
# > I'm going to erase your memory
# Bot: i m not . . . !
# > q

# %% [markdown]
# ### Beam Search Decoding

# %% [markdown]
# So far, we used **greedy decoding**, which selects the most likely next token at each step.
# Greedy decoding is fast, but it may miss better full sequences because it commits to local choices.
#
# In this task you will implement **beam search**, as discussed in class.
# Beam search keeps the top-*k* partial hypotheses at each decoding step, ranked by their cumulative log-probability.
#
# **Requirements**
# - Implement `BeamSearchDecoder` similar in interface to `GreedySearchDecoder`.
# - Use beam width `k` (beam size) as a configurable argument.
# - Use **log-probabilities** (sum of log-probs) to score sequences.
# - Stop a hypothesis when it emits `EOS_token` (you may keep completed hypotheses in a separate list).
# - Return the best decoded token sequence (and optionally its scores).

# %%
class BeamSearchDecoder(nn.Module):
    def __init__(self, encoder, decoder, beam_size=5):
        super(BeamSearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.beam_size = beam_size

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)

        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:self.decoder.n_layers]

        # Initialize beam with SOS token
        # Each beam entry: (log_prob, token_sequence, hidden_state, finished)
        beams = [(0.0, [SOS_token], decoder_hidden, False)]
        completed = []

        for _ in range(max_length):
            new_beams = []

            for log_prob, seq, hidden, finished in beams:
                if finished:
                    completed.append((log_prob, seq, hidden, finished))
                    continue

                # Get last token
                last_token = seq[-1]
                decoder_input = torch.LongTensor([[last_token]]).to(device)

                # Forward pass through decoder
                decoder_output, new_hidden = self.decoder(decoder_input, hidden, encoder_outputs)

                # Get log probabilities
                log_probs = torch.log(decoder_output + 1e-10)  # Add small epsilon to avoid log(0)

                # Get top k tokens
                topk_log_probs, topk_indices = log_probs.topk(self.beam_size, dim=1)

                for i in range(self.beam_size):
                    token = topk_indices[0][i].item()
                    token_log_prob = topk_log_probs[0][i].item()
                    new_log_prob = log_prob + token_log_prob
                    new_seq = seq + [token]
                    is_finished = (token == EOS_token)

                    if is_finished:
                        completed.append((new_log_prob, new_seq, new_hidden, True))
                    else:
                        new_beams.append((new_log_prob, new_seq, new_hidden, False))

            # Keep top beam_size beams
            new_beams.sort(key=lambda x: x[0], reverse=True)
            beams = new_beams[:self.beam_size]

            # If all beams are finished, break
            if not beams:
                break

        # Add remaining beams to completed
        completed.extend(beams)

        # Select best sequence
        if completed:
            completed.sort(key=lambda x: x[0], reverse=True)
            best_seq = completed[0][1]
        else:
            best_seq = [SOS_token, EOS_token]

        # Remove SOS token and convert to tensors
        if best_seq[0] == SOS_token:
            best_seq = best_seq[1:]

        # Remove EOS token if present
        if EOS_token in best_seq:
            eos_idx = best_seq.index(EOS_token)
            best_seq = best_seq[:eos_idx]

        all_tokens = torch.LongTensor(best_seq).to(device)
        all_scores = torch.zeros(len(best_seq)).to(device)  # Placeholder scores

        return all_tokens, all_scores

# %% [markdown]
# Run the following cell and try the **same 10 prompts** with greedy vs. beam search.
# Briefly comment: do you observe differences? When might beam search help, and when might it hurt?

# %%
greedy_searcher = GreedySearchDecoder(encoder, decoder)
beam_searcher = BeamSearchDecoder(encoder, decoder)

evaluateInput(encoder, decoder, greedy_searcher, voc)
evaluateInput(encoder, decoder, beam_searcher, voc)
# Out:
# > hello
# Bot: hello . . . . .
# > how are you
# Bot: i m not okay . . .
# > are you good
# Bot: i m not . . .
# > nice
# Bot: i m sorry . . . .
# > I'm not
# Bot: you re a bit girl . . .
# > you're a byte robot
# Bot: i m laying . . .
# > stand up
# Bot: i m sorry . . . !
# > okay
# Bot: okay . i m okay . .
# > I've got that
# Bot: you ve got to get up . .
# > I'm fine sitting down
# Bot: i m sorry . . . !
# > q
# > hello
# Bot: hello .
# > how are you
# Bot: fine .
# > are you good
# Bot: i am .
# > nice
# Bot: i m sorry .
# > I'm not
# Bot: you re not .
# > you're a byte robot
# Bot: no .
# > stand up
# Bot: i m sorry .
# > okay
# Bot: okay .
# > I've got that
# Bot: what ?
# > I'm fine sitting down
# Bot: i m sorry .
# > q

# %% [markdown]
# <font color='red'>
# Greedy search produced shorter, cleaner responses (e.g., "fine .", "i am ."), while beam search tended to generate longer outputs with repetitive patterns (e.g., "i m not okay . . .").
#
# Beam search may help when generating longer, complex sentences where early token choices affect later quality. It can hurt when it leads to repetitive or generic outputs, as seen here. For short conversational responses, greedy performed comparably or better.
# </font>

# %% [markdown]
# ### Understanding & Reflection Questions

# %% [markdown]
# Answer the following questions in your own words.
# Your answers should demonstrate conceptual understanding rather than
# code-level details.
#
# 1. **Dataset Understanding**
#    What is the *Cornell Movie-Dialogs Corpus*?
#    Describe the type of data it contains and explain how it is used in
#    this assignment to formulate a learning problem.
#     <font color='red'>
#    The Cornell Movie-Dialogs Corpus is a collection of conversational exchanges from movie scripts. It contains dialogue between characters, structured as conversation turns. In this assignment, a single training example consists of a query-response pair: an input sentence (the query) and its corresponding response. This format is appropriate because it naturally frames conversation as a sequence-to-sequence problem where the model learns to generate appropriate responses given input queries.
#     </font>
#
# 2. **Vocabulary Construction**
#    We implemented a custom `Voc` class to manage the vocabulary.
#    What object or mechanism did we use in class (Tutorials 9–10) to obtain similar functionality?
#    Compare the two approaches at a high level.
#  <font color='red'>
#    In class, we used `torchtext`'s `Field` and `Vocab` classes for similar functionality. The custom `Voc` class implemented here manually handles:
#
# - `word2index`: maps words to indices
# - `index2word`: maps indices back to words
# - `word2count`: tracks word frequencies for trimming
# The torchtext approach provides similar functionality but with additional features like automatic batching and pre-built pipelines. The manual approach gives more control but requires more implementation effort.
#  </font>
#
# 3. **Model Architecture**
#    Describe the model architecture used in this assignment *abstractly*.
#    Your answer should explain the roles of the encoder, decoder, and
#    attention mechanism, without referring to specific code details.
#
#     <font color='red'>
# The model follows the encoder-decoder architecture:
# - **Encoder**: A bidirectional GRU that reads the input sentence and produces hidden representations capturing context from both directions.
# - **Decoder**: A unidirectional GRU that generates the response one token at a time.
# - **Attention**: Allows the decoder to focus on relevant parts of the input at each decoding step by computing weighted combinations of encoder outputs.
#      </font>
#
# 4. **Input Representation**
#    What is the dimensionality of each input vector in the sequences fed
#    into the model?
#    Which constant in the implementation determines this dimension, and what does it represent?
#
#   <font color='red'>
#   Each input vector has dimensionality equal to `hidden_size` (500 in this assignment). This constant determines the embedding dimension and the hidden state size of the RNNs. It represents the capacity of the model to capture semantic information.
#   </font>
#
# 5. **Batch Construction**
#    How are training batches constructed in this assignment?
#    Explain how variable-length sequences are handled and why padding,
#    masking, and sorting by sequence length are necessary.
#
#     <font color='red'>
#     Training batches are constructed by:
# - Sorting sentence pairs by input length (descending) for efficient packed sequence processing
# - Padding shorter sequences with PAD tokens to match the longest sequence
# - Creating masks to ignore padding during loss computation
# This is necessary because RNNs require f
#     </font>
#
# 6. **Packed Sequences Efficiency**
#    The function `torch.nn.utils.rnn.pack_padded_sequence` improves
#    computational efficiency by removing padding tokens before passing
#    sequences to the RNN.
#
#    Given the following batch of sequences:
#
#     ```
#     [torch.tensor([10]),
#     torch.tensor([1, 2, 3]),
#     torch.tensor([4, 5]),
#     torch.tensor([6, 7, 8, 9])]
#     ```
#
#
#     By what factor does `pack_padded_sequence` reduce the number of inputs
#     processed by the RNN, compared to processing the padded batch directly?
#     Show your reasoning.
#
#    <font color='red'>
#   Given sequences: [10], [1,2,3], [4,5], [6,7,8,9]
#   - Padded processing: 4 sequences × 4 time steps = 16 RNN steps
#   - Actual tokens: 1 + 3 + 2 + 4 = 10 tokens
#   - Reduction factor: 16/10 = 1.6× (pack_padded_sequence reduces computation by 37.5%)
#      </font>

# %% [markdown]
# ## Neural Machine Translation with Sequence-to-Sequence Models (35 Points)
#
# In this question, we turn our attention to **Neural Machine Translation (NMT)** — the task of automatically translating sentences from one natural language to another using neural networks.
#
# Machine translation has long been a central problem in artificial intelligence and natural language processing. Early approaches relied on hand-crafted linguistic rules, followed by large-scale **statistical machine translation (SMT)** systems that modeled translation as a probabilistic inference problem over phrase tables and alignment models. While these methods achieved notable success, they required complex pipelines and extensive feature engineering.
#
# The advent of deep learning introduced a fundamentally different paradigm: instead of explicitly modeling alignments and translation rules, we can train a neural network to **directly map a sentence in one language to a sentence in another**. This idea was popularized by the *sequence-to-sequence* framework, where an encoder network reads an input sequence and a decoder network generates an output sequence, one token at a time.
#
# In this question, we study neural machine translation through a classical and instructive architecture: an **encoder–decoder model with recurrent neural networks**. Concretely, we will work with a **Spanish $\to$ English** translation task, where each training example consists of a Spanish source sentence and its corresponding English translation.
#
#
# Throughout the question, we will move step by step from data representation, through model construction, to qualitative and quantitative analysis of translation behavior.

# %% [markdown]
# > Start by Importing Libraries:

# %%
# Import Libraries

import os
import re
import math
import random
import time
from collections import Counter
from dataclasses import dataclass
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, Sampler
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence

# %% [markdown]
# ### Data Loading & Preprocessing

# %% [markdown]
# The next step is to load and organize the data that will serve as the foundation for our translation model.
#
# We work with a **Portuguese–English parallel translation dataset derived from TED Talks**, where each example consists of a spoken Portuguese sentence and its corresponding English translation. The dataset contains sentence-level alignments, making it suitable for supervised sequence-to-sequence learning.
#
# Our dataset consists of **paired Portuguese–English sentences**, where each example contains a Portuguese source sentence and its corresponding English translation. Together, these pairs form a **parallel corpus**, which is the standard training format for neural machine translation systems.
#
# The data spans a wide range of sentence lengths, syntactic structures, and semantic content. Some sentence pairs are short and literal, while others involve rephrasing, reordering, or stylistic adaptation between languages. This variability reflects the nature of real-world translation tasks, where a correct translation often depends on meaning rather than surface-level word alignment.
#
# Because both the input and output are **natural language sequences of variable length**, this dataset immediately poses several practical challenges:
# - sentences must be represented in a numerical form,
# - different sentence lengths must be handled efficiently,
# - and the model must learn when to begin and when to stop generating a translation.
#
# Before defining any neural architecture, we therefore begin by
# reformatting the raw sentence pairs into structures that can be consumed by a learning algorithm.
#
# We start by examining a small subset of the data to understand its basic structure.

# %% [markdown]
# > Run the following cells to load the translation dataset:

# %%
# !pip -q install -U tensorflow-datasets

import tensorflow_datasets as tfds

# sanity: make sure the dataset builder exists
print("TFDS version:", tfds.__version__)
print("Has ted_hrlr_translate?", "ted_hrlr_translate" in tfds.list_builders())
# Out:
# TFDS version: 4.9.9
# Has ted_hrlr_translate? True

# %%
# Load Portuguese → English TED Talks data
train_ds = tfds.load("ted_hrlr_translate/pt_to_en", split="train", as_supervised=True)
val_ds   = tfds.load("ted_hrlr_translate/pt_to_en", split="validation", as_supervised=True)
test_ds  = tfds.load("ted_hrlr_translate/pt_to_en", split="test", as_supervised=True)

print(train_ds, val_ds, test_ds)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/incomplete.1ML8XM_1.0.0/ted_hrlr_translate-tra…
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/incomplete.1ML8XM_1.0.0/ted_hrlr_translate-val…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/incomplete.1ML8XM_1.0.0/ted_hrlr_translate-tes…
# Dataset ted_hrlr_translate downloaded and prepared to /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0. Subsequent calls will reuse this data.
# <_PrefetchDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.string, name=None))> <_PrefetchDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.string, name=None))> <_PrefetchDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.string, name=None))>

# %% [markdown]
# For convenience, the dataset is loaded using **TensorFlow Datasets**.
# However, all subsequent preprocessing, modeling, and training steps in
# this question are implemented entirely in **PyTorch**.
#
# We therefore begin by converting the TensorFlow tensors into standard
# Python lists that can be easily manipulated and later transformed into
# PyTorch tensors.

# %%
def tfds_to_lists(ds, max_examples=None):
    src, tgt = [], []
    for i, (s, t) in enumerate(tfds.as_numpy(ds)):
        src.append(s.decode("utf-8"))
        tgt.append(t.decode("utf-8"))
        if max_examples is not None and i + 1 >= max_examples:
            break
    return src, tgt

# Limit sizes to keep training manageable
MAX_TRAIN = 60000
MAX_VAL   = 2000
MAX_TEST  = 2000

train_pt, train_en = tfds_to_lists(train_ds, MAX_TRAIN)
val_pt,   val_en   = tfds_to_lists(val_ds,   MAX_VAL)
test_pt,  test_en  = tfds_to_lists(test_ds,  MAX_TEST)

print("Train:", len(train_pt))
print("Val:", len(val_pt))
print("Test:", len(test_pt))
# Out:
# Train: 51785
# Val: 1193
# Test: 1803

# %% [markdown]
# As a sanity check, we will also print a small number of paired sentences
# to inspect the raw Portuguese–English data.

# %%
for i in range(5):
    print("PT:", train_pt[i])
    print("EN:", train_en[i])
    print("-" * 60)
# Out:
# PT: e quando melhoramos a procura , tiramos a única vantagem da impressão , que é a serendipidade .
# EN: and when you improve searchability , you actually take away the one advantage of print , which is serendipity .
# ------------------------------------------------------------
# PT: mas e se estes fatores fossem ativos ?
# EN: but what if it were active ?
# ------------------------------------------------------------
# PT: mas eles não tinham a curiosidade de me testar .
# EN: but they did n't test for curiosity .
# ------------------------------------------------------------
# PT: e esta rebeldia consciente é a razão pela qual eu , como agnóstica , posso ainda ter fé .
# EN: and this conscious defiance is why i , as an agnostic , can still have faith .
# ------------------------------------------------------------
# PT: `` `` '' podem usar tudo sobre a mesa no meu corpo . ''
# EN: you can use everything on the table on me .
# ------------------------------------------------------------

# %% [markdown]
# #### Tokenization

# %% [markdown]
# As discussed in class, neural networks do not operate directly on raw
# text. In order to process a sentence with a neural model, we must first
# convert it into a numerical representation.
#
# The standard approach is to represent each sentence as a sequence of
# **tokens**, where each token corresponds to a word drawn from a fixed
# vocabulary. Each word is then mapped to a unique integer index, so that a
# sentence can be viewed as a sequence of integers rather than a sequence
# of strings.
#
# In a translation setting, this process must be carried out **separately**
# for the source language (Portuguese) and the target language (English),
# since the two languages have distinct vocabularies and linguistic
# structure.
#
# As we have seen, practical sequence models also rely on a small number of
# **special tokens** that encode structural information:
# - a padding token, used to align sequences of different lengths,
# - a token marking the beginning of a target sentence,
# - a token marking the end of a target sentence,
# - and a token representing unknown or rare words.
#
# These tokens allow the model to distinguish between meaningful content
# and structural boundaries, and will play an important role throughout
# the translation pipeline.
#
# We therefore begin by explicitly defining these special tokens and
# setting up the basic machinery needed to map text sequences into
# numerical form.

# %% [markdown]
# In this part, you will implement tokenization - the machinery that converts raw text sentences into sequences of integer indices.
#
# Specifically, you should:
# - define a simple tokenization scheme,
# - build separate vocabularies for Portuguese and English,
# - reserve indices for special tokens (`<pad>`, `<unk>`, `<bos>`, `<eos>`),
# - and implement methods for encoding sentences as index sequences and
#   decoding them back to text.

# %%
# Reuse special tokens defined earlier
PAD_TOKEN = "<pad>"
UNK_TOKEN = "<unk>"
BOS_TOKEN = "<bos>"
EOS_TOKEN = "<eos>"

SPECIAL_TOKENS = [PAD_TOKEN, UNK_TOKEN, BOS_TOKEN, EOS_TOKEN]

def tokenize(sentence: str):
    return sentence.strip().split()


class Vocabulary:
    def __init__(self, sentences, min_freq=2):
        """
        sentences: list of raw text sentences
        min_freq : minimum frequency for a word to be included
        """
        counter = Counter()
        for sent in sentences:
            counter.update(tokenize(sent))

        # Initialize vocab with special tokens
        self.itos = list(SPECIAL_TOKENS)
        self.stoi = {tok: i for i, tok in enumerate(self.itos)}

        # Add frequent words
        for word, freq in counter.items():
            if freq >= min_freq and word not in self.stoi:
                self.stoi[word] = len(self.itos)
                self.itos.append(word)

    def encode(self, sentence, add_bos=False, add_eos=False):
        tokens = tokenize(sentence)
        ids = [self.stoi.get(tok, self.stoi[UNK_TOKEN]) for tok in tokens]

        if add_bos:
            ids = [self.stoi[BOS_TOKEN]] + ids
        if add_eos:
            ids = ids + [self.stoi[EOS_TOKEN]]

        return ids

    def decode(self, ids):
        words = []
        for idx in ids:
            word = self.itos[idx]
            if word in {BOS_TOKEN, PAD_TOKEN}:
                continue
            if word == EOS_TOKEN:
                break
            words.append(word)
        return " ".join(words)

    def __len__(self):
        return len(self.itos)


# Build vocabularies
pt_vocab = Vocabulary(train_pt, min_freq=2)
en_vocab = Vocabulary(train_en, min_freq=2)

print("Portuguese vocab size:", len(pt_vocab))
print("English vocab size:", len(en_vocab))
# Out:
# Portuguese vocab size: 21778
# English vocab size: 16517

# %% [markdown]
# Before proceeding, we perform a simple sanity check to verify that the vocabulary and encoding logic behave as expected.
#
# In particular, we encode a sample sentence into a sequence of indices and then decode it back into text. This allows us to confirm that common words are preserved correctly and that rare or unseen words are handled in a consistent manner.

# %%
# Encode and decode a sample sentence
pt_example = train_pt[0]
encoded = pt_vocab.encode(pt_example, add_bos=True, add_eos=True)
decoded = pt_vocab.decode(encoded)

print("Original:", pt_example)
print("Encoded:", encoded[:10], "...")
print("Decoded:", decoded)
# Out:
# Original: e quando melhoramos a procura , tiramos a única vantagem da impressão , que é a serendipidade .
# Encoded: [2, 4, 5, 6, 7, 8, 9, 10, 7, 11] ...
# Decoded: e quando melhoramos a procura , tiramos a única vantagem da impressão , que é a <unk> .

# %% [markdown]
# #### Length-Aware Batching (Bucketing)

# %% [markdown]
# As discussed in class, natural language sentences vary significantly in
# length. When such sequences are grouped into mini-batches, shorter
# sentences must be padded to match the length of the longest sentence in
# the batch.
#
# Excessive padding is computationally wasteful: it increases memory
# usage, slows down training, and introduces artificial tokens that carry
# no semantic information. This issue becomes especially pronounced when a
# batch contains a mix of very short and very long sentences.
#
# A common remedy is **bucketing**, where examples of similar sequence
# lengths are grouped together into the same mini-batch. By batching
# sentences with comparable lengths, we substantially reduce the amount
# of padding required while preserving the efficiency benefits of
# mini-batch training.
#
# In this question, we adopt a BucketIterator-style batching strategy. We
# retain full control over tokenization and vocabulary construction, while
# using length-aware batching to ensure efficient training of our
# sequence-to-sequence model.

# %%
class TranslationDataset(Dataset):
    def __init__(self, src_sentences, tgt_sentences, src_vocab, tgt_vocab):
        assert len(src_sentences) == len(tgt_sentences)
        self.src = src_sentences
        self.tgt = tgt_sentences
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab

    def __len__(self):
        return len(self.src)

    def __getitem__(self, idx):
        src_ids = self.src_vocab.encode(self.src[idx])
        tgt_ids = self.tgt_vocab.encode(self.tgt[idx], add_bos=True, add_eos=True)
        return src_ids, tgt_ids

def collate_fn(batch):
    src_batch, tgt_batch = zip(*batch)

    src_lens = torch.tensor([len(x) for x in src_batch], dtype=torch.long)
    tgt_lens = torch.tensor([len(x) for x in tgt_batch], dtype=torch.long)

    src_pad = pad_sequence(
        [torch.tensor(x, dtype=torch.long) for x in src_batch],
        batch_first=True,
        padding_value=pt_vocab.stoi[PAD_TOKEN]
    )
    tgt_pad = pad_sequence(
        [torch.tensor(x, dtype=torch.long) for x in tgt_batch],
        batch_first=True,
        padding_value=en_vocab.stoi[PAD_TOKEN]
    )

    return src_pad, src_lens, tgt_pad, tgt_lens

class BucketBatchSampler(Sampler):
    def __init__(self, lengths, batch_size, bucket_size=2048, shuffle=True, drop_last=False):
        self.lengths = np.asarray(lengths)
        self.batch_size = batch_size
        self.bucket_size = bucket_size
        self.shuffle = shuffle
        self.drop_last = drop_last
        self.indices = np.arange(len(self.lengths))

    def __iter__(self):
        idxs = self.indices.copy()
        if self.shuffle:
            np.random.shuffle(idxs)

        for i in range(0, len(idxs), self.bucket_size):
            bucket = idxs[i:i + self.bucket_size]
            bucket = bucket[np.argsort(self.lengths[bucket])]

            for j in range(0, len(bucket), self.batch_size):
                batch = bucket[j:j + self.batch_size]
                if self.drop_last and len(batch) < self.batch_size:
                    continue
                yield batch.tolist()

    def __len__(self):
        n = len(self.indices) // self.batch_size
        if not self.drop_last and len(self.indices) % self.batch_size != 0:
            n += 1
        return n

train_dataset = TranslationDataset(train_pt, train_en, pt_vocab, en_vocab)
val_dataset   = TranslationDataset(val_pt,   val_en,   pt_vocab, en_vocab)

train_src_lengths = [len(pt_vocab.encode(s)) for s in train_pt]
val_src_lengths   = [len(pt_vocab.encode(s)) for s in val_pt]

BATCH_SIZE = 16  # You may experiment with other batch sizes

train_sampler = BucketBatchSampler(train_src_lengths, batch_size=BATCH_SIZE, bucket_size=2048, shuffle=True)
val_sampler   = BucketBatchSampler(val_src_lengths,   batch_size=BATCH_SIZE, bucket_size=2048, shuffle=False)

train_loader = DataLoader(train_dataset, batch_sampler=train_sampler, collate_fn=collate_fn)
val_loader   = DataLoader(val_dataset,   batch_sampler=val_sampler,   collate_fn=collate_fn)

print("Train batches:", len(train_loader))
print("Val batches:", len(val_loader))
# Out:
# Train batches: 3237
# Val batches: 75

# %% [markdown]
# Before introducing any neural model, we verify that batching behaves as
# expected.
#
# In particular, we check that:
# - sequences are padded correctly,
# - padding uses the `<pad>` token,
# - and the reported sequence lengths match the unpadded data.

# %%
src_pad, src_lens, tgt_pad, tgt_lens = next(iter(train_loader))

print("Source batch shape:", src_pad.shape)
print("Target batch shape:", tgt_pad.shape)
print("Source lengths (first 5):", src_lens[:5].tolist())
print("Target lengths (first 5):", tgt_lens[:5].tolist())
# Out:
# Source batch shape: torch.Size([16, 3])
# Target batch shape: torch.Size([16, 7])
# Source lengths (first 5): [1, 2, 2, 2, 2]
# Target lengths (first 5): [5, 4, 4, 5, 5]

# %% [markdown]
# ### Model Architecture

# %% [markdown]
# We now describe the complete neural machine translation model that we will implement in this question.
#
# Our system follows the classical **sequence-to-sequence (Seq2Seq)** framework with attention. The model consists of an **encoder** that reads a source sentence in Portuguese and a **decoder** that generates an English translation one token at a time. An **attention mechanism** connects the two, allowing the decoder to selectively focus on different parts of the source sentence during generation.
#
# The figure below illustrates the model at a single decoding timestep.
# The encoder processes the entire source sentence and produces a sequence of hidden states. At each decoding step, the decoder computes attention weights over these encoder states, forms a context vector, and combines it with its current hidden state to predict the next target word.
#
# In the remainder of this question, we will implement this model hierarchically, breaking it down into the following components.

# %% [markdown]
# ![Model Architecture](https://raw.githubusercontent.com/NaamanKopty/Deep-Learning-Course/main/HW3/model_architecture.png)

# %% [markdown]
# #### Encoder

# %% [markdown]
# In this part, you will implement the **encoder**, which reads a Portuguese source sentence
# and produces contextual hidden representations for each source token.
#
# **What to define (layers):**
# 1. **Source embedding**
#    - An embedding layer that maps token indices to vectors:
#      - input: `(B, T_src)` integer token ids
#      - output: `(B, T_src, E)` embeddings
#    - Make sure the `<pad>` token uses `padding_idx` so it does not get trained as a normal token.
#
# 2. **Bidirectional LSTM**
#    - A 1-layer bidirectional LSTM that processes the embedded sequence.
#    - Use packed sequences (with `src_lens`) so the LSTM does not waste computation on padding.
#    - It should output encoder hidden states:
#      - `enc_hiddens`: `(B, T_src, 2H)`  (because bidirectional)
#
# 3. **Dropout**
#    - Apply dropout to embeddings (and/or to the LSTM outputs) for regularization.
#
# **Forward input:**
# - `src_pad`: padded source batch of shape `(B, T_src)`
# - `src_lens`: true lengths of shape `(B,)`
#
# **Forward output:**
# - `enc_hiddens`: `(B, T_src, 2H)`
# - raw final states `(h_n, c_n)` from the BiLSTM:
#   - each of shape `(2, B, H)` (forward + backward)

# %%
class EncoderBiLSTM(nn.Module):
    def __init__(self, src_vocab_size, emb_dim, hidden_dim, pad_idx, dropout=0.1):
        super().__init__()
        self.hidden_dim = hidden_dim

        # Source embedding with padding
        self.embedding = nn.Embedding(src_vocab_size, emb_dim, padding_idx=pad_idx)

        # Bidirectional LSTM
        self.lstm = nn.LSTM(
            input_size=emb_dim,
            hidden_size=hidden_dim,
            num_layers=1,
            bidirectional=True,
            batch_first=True
        )

        self.dropout = nn.Dropout(dropout)

    def forward(self, src_pad, src_lens):
        # src_pad: (B, T_src)
        # Embed
        embedded = self.dropout(self.embedding(src_pad))  # (B, T_src, E)

        # Pack padded sequence
        packed = pack_padded_sequence(
            embedded,
            src_lens.cpu(),
            batch_first=True,
            enforce_sorted=False
        )

        # Forward through LSTM
        packed_outputs, (h_n, c_n) = self.lstm(packed)

        # Unpack
        enc_hiddens, _ = pad_packed_sequence(packed_outputs, batch_first=True)
        # enc_hiddens: (B, T_src, 2H)

        # h_n, c_n: (2, B, H) - forward and backward
        return enc_hiddens, (h_n, c_n)

# %% [markdown]
# #### Attention Mechanism

# %% [markdown]
# In this part, we implement the **attention mechanism** that connects the decoder to the encoder.
#
# At each decoding timestep, the decoder has a hidden state `h_t` of shape `(B, H)`.
# The encoder produced a sequence of hidden states `enc_hiddens` of shape `(B, T_src, 2H)`.
#
# We compute a relevance score between `h_t` and every encoder state, normalize these scores with a softmax to obtain attention weights over the source positions, and then compute a **context vector** as a weighted sum of encoder states.
#
# Because the encoder states have dimension `2H` while the decoder state has dimension `H`, we first project encoder states to dimension `H` so that the dot product is well-defined.
#
# Padding positions in the source should not receive attention, so we apply a mask based on `src_lens`.

# %%
class DotProductAttention(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        # Project encoder states from 2H to H for dot product with decoder states
        self.enc_proj = nn.Linear(2 * hidden_dim, hidden_dim, bias=False)

    def forward(self, dec_h, enc_hiddens, src_lens):
        """
        dec_h: (B, H) - current decoder hidden state
        enc_hiddens: (B, T_src, 2H) - encoder outputs
        src_lens: (B,) - source lengths for masking

        Returns:
            context: (B, 2H) - context vector
            attn_weights: (B, T_src) - attention weights
        """
        B, T_src, _ = enc_hiddens.size()
        device = enc_hiddens.device

        # Move src_lens to the same device as enc_hiddens
        src_lens = src_lens.to(device)

        # Project encoder hiddens to H dimensions
        enc_proj = self.enc_proj(enc_hiddens)  # (B, T_src, H)

        # Compute attention scores
        scores = torch.bmm(enc_proj, dec_h.unsqueeze(2)).squeeze(2)  # (B, T_src)

        # Create mask for padding positions
        max_len = T_src
        mask = torch.arange(max_len, device=device).unsqueeze(0) >= src_lens.unsqueeze(1)

        # Apply mask (set padding positions to very negative value)
        scores = scores.masked_fill(mask, float('-inf'))

        # Softmax to get attention weights
        attn_weights = F.softmax(scores, dim=1)  # (B, T_src)

        # Compute context vector
        context = torch.bmm(attn_weights.unsqueeze(1), enc_hiddens).squeeze(1)  # (B, 2H)

        return context, attn_weights

# %% [markdown]
# #### Decoder

# %% [markdown]
# We now implement the **decoder**, which generates the English sentence autoregressively.
#
# During training we use **teacher forcing**:
# - the decoder input at time `t` is the *ground-truth* target token at time `t`
# - the model predicts the token at time `t+1`
#
# Before decoding begins, the decoder must be provided with an **initial hidden state** and **initial cell state**. Our encoder is a *bidirectional* LSTM, so its final states
# come from two directions (forward and backward). The decoder, however, is a *unidirectional* LSTM and therefore expects a single initial hidden/cell state.
#
# To bridge this mismatch, we define a small **decoder initializer** module that:
# 1. Takes the encoder’s final forward and backward states,
# 2. Concatenates them into a `(B, 2H)` vector,
# 3. Projects them to `(B, H)` to obtain the decoder’s initial hidden and cell states.
#
# Once initialized, decoding proceeds as follows:
# 1. Embed the input target tokens (excluding the last token).
# 2. Run a unidirectional LSTM to update the decoder hidden state at each timestep.
# 3. Use attention to compute a context vector from the encoder hidden states.
# 4. Combine the decoder hidden state and context vector to form an **attentional vector** that will later be mapped to vocabulary logits.
#
# The decoder returns a sequence of attentional vectors of shape `(B, T_tgt-1, H)`.

# %%
class DecoderInit(nn.Module):
    """
    Projects final BiLSTM encoder states -> initial UniLSTM decoder states.
    """
    def __init__(self, hidden_dim):
        super().__init__()
        # Project concatenated forward+backward states (2H) to decoder dim (H)
        self.h_proj = nn.Linear(2 * hidden_dim, hidden_dim)
        self.c_proj = nn.Linear(2 * hidden_dim, hidden_dim)

    def forward(self, h_n, c_n):
        """
        h_n, c_n: (2, B, H) - forward and backward final states
        Returns: h0_dec, c0_dec each (B, H)
        """
        # Concatenate forward (h_n[0]) and backward (h_n[1]) states
        h_cat = torch.cat([h_n[0], h_n[1]], dim=1)  # (B, 2H)
        c_cat = torch.cat([c_n[0], c_n[1]], dim=1)  # (B, 2H)

        # Project to decoder dimension
        h0_dec = torch.tanh(self.h_proj(h_cat))  # (B, H)
        c0_dec = torch.tanh(self.c_proj(c_cat))  # (B, H)

        return h0_dec, c0_dec

# %%
class Decoder(nn.Module):
    def __init__(self, tgt_vocab_size, emb_dim, hidden_dim, pad_idx, dropout=0.1):
        super().__init__()
        self.hidden_dim = hidden_dim

        # Target embedding
        self.embedding = nn.Embedding(tgt_vocab_size, emb_dim, padding_idx=pad_idx)

        # LSTM cell (unidirectional)
        self.lstm_cell = nn.LSTMCell(
            input_size=emb_dim,
            hidden_size=hidden_dim
        )

        # Attention
        self.attention = DotProductAttention(hidden_dim)

        # Combine decoder hidden + context (H + 2H = 3H) -> attentional vector (H)
        self.attn_combine = nn.Linear(hidden_dim + 2 * hidden_dim, hidden_dim)

        self.dropout = nn.Dropout(dropout)

    def forward(self, tgt_pad, dec_init_state, enc_hiddens, src_lens):
        """
        tgt_pad: (B, T_tgt) includes <bos> ... <eos>
        dec_init_state: (h0_dec, c0_dec) each (B, H)
        enc_hiddens: (B, T_src, 2H)
        src_lens: (B,)

        Returns:
            attn_vecs: (B, T_tgt-1, H)
        """
        B, T_tgt = tgt_pad.size()

        # Embed target (exclude last token as we predict it)
        tgt_emb = self.dropout(self.embedding(tgt_pad[:, :-1]))  # (B, T_tgt-1, E)

        h, c = dec_init_state  # Each (B, H)

        attn_vecs = []

        for t in range(T_tgt - 1):
            # Get input embedding for this time step
            emb_t = tgt_emb[:, t, :]  # (B, E)

            # LSTM cell forward
            h, c = self.lstm_cell(emb_t, (h, c))  # h, c: (B, H)

            # Compute attention and context
            context, _ = self.attention(h, enc_hiddens, src_lens)  # context: (B, 2H)

            # Combine decoder hidden state and context
            combined = torch.cat([h, context], dim=1)  # (B, 3H)
            attn_vec = torch.tanh(self.attn_combine(combined))  # (B, H)

            attn_vecs.append(attn_vec)

        # Stack along time dimension
        attn_vecs = torch.stack(attn_vecs, dim=1)  # (B, T_tgt-1, H)

        return attn_vecs

# %% [markdown]
# #### Output Projection

# %% [markdown]
# At each decoding timestep, the decoder produces an attentional vector of shape `(B, H)`.
# This vector is a continuous representation, but the task requires predicting a discrete token from the target vocabulary.
#
# We therefore apply a learned linear transformation that maps:
# - from hidden dimension `H`
# - to target vocabulary size `|V_tgt|`
#
# This produces **logits** (unnormalized scores) of shape `(B, T_tgt-1, |V_tgt|)`.
# During training, these logits are used with the cross-entropy loss (while ignoring `<pad>` tokens).

# %%
class OutputProjection(nn.Module):
    def __init__(self, hidden_dim, tgt_vocab_size):
        super().__init__()
        self.proj = nn.Linear(hidden_dim, tgt_vocab_size)

    def forward(self, attn_vecs):
        """
        attn_vecs: (B, T, H)
        Returns:
            logits: (B, T, |V_tgt|)
        """
        return self.proj(attn_vecs)

# %% [markdown]
# #### Full Model Definition

# %% [markdown]
# At this stage, all individual components of the translation model have been implemented: the encoder, the decoder initialization, the decoder with attention, and the output projection.
#
# The full translation model simply **connects these components into a single forward computation**. It does not introduce any new architectural ideas; rather, it defines how data flows through the model during training.
#
# Concretely, the full model performs the following steps:
# 1. Encode the source sentence using the encoder to obtain encoder hidden states.
# 2. Use the final encoder states to initialize the decoder’s hidden and cell states.
# 3. Run the decoder with attention over the encoder states to produce a sequence of decoder representations.
# 4. Apply the output projection to map decoder representations to vocabulary logits.
#
# The model’s forward method returns the unnormalized logits for all target
# positions, which will later be used to compute the training loss.

# %%
class Seq2SeqNMT(nn.Module):
    def __init__(self, encoder, decoder, dec_init, out_proj):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.dec_init = dec_init
        self.out_proj = out_proj

    def forward(self, src_pad, src_lens, tgt_pad):
        """
        src_pad: (B, T_src)
        src_lens: (B,)
        tgt_pad: (B, T_tgt)

        Returns:
            logits: (B, T_tgt-1, |V_tgt|)
        """
        # 1. Encode source
        enc_hiddens, (h_n, c_n) = self.encoder(src_pad, src_lens)

        # 2. Initialize decoder state
        h0_dec, c0_dec = self.dec_init(h_n, c_n)

        # 3. Decode
        attn_vecs = self.decoder(tgt_pad, (h0_dec, c0_dec), enc_hiddens, src_lens)

        # 4. Project to vocabulary
        logits = self.out_proj(attn_vecs)

        return logits

# %% [markdown]
# ### Training

# %% [markdown]
# We now train our neural machine translation model end-to-end.
#
# The model is trained for **25 epochs** using the **Adam** optimizer. The training objective is **token-level cross-entropy loss**, computed over the target sequence under **teacher forcing**. Padding tokens (`<pad>`) do not correspond to real words and are therefore ignored when computing the loss.
#
# After each training epoch, the model is evaluated on a held-out **validation set** (without updating parameters). We record:
# - the average **training loss per token**
# - the average **validation loss per token**
#
# Monitoring both quantities allows us to track learning progress and identify potential overfitting.
#
# Finally, we plot the training and validation loss curves as a function of epoch. Both curves should appear on the same graph for comparison.

# %%
# Hyperparameters
EMB_DIM = 256
HIDDEN_DIM = 256
DROPOUT = 0.3
NUM_EPOCHS = 25
LEARNING_RATE = 1e-3

# Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Get pad indices
PAD_IDX_SRC = pt_vocab.stoi[PAD_TOKEN]
PAD_IDX_TGT = en_vocab.stoi[PAD_TOKEN]

# Build model components
encoder = EncoderBiLSTM(
    src_vocab_size=len(pt_vocab),
    emb_dim=EMB_DIM,
    hidden_dim=HIDDEN_DIM,
    pad_idx=PAD_IDX_SRC,
    dropout=DROPOUT
)

decoder = Decoder(
    tgt_vocab_size=len(en_vocab),
    emb_dim=EMB_DIM,
    hidden_dim=HIDDEN_DIM,
    pad_idx=PAD_IDX_TGT,
    dropout=DROPOUT
)

dec_init = DecoderInit(HIDDEN_DIM)
out_proj = OutputProjection(HIDDEN_DIM, len(en_vocab))

# Full model
model = Seq2SeqNMT(encoder, decoder, dec_init, out_proj).to(device)

# Optimizer and loss
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
criterion = nn.CrossEntropyLoss(ignore_index=PAD_IDX_TGT)

# Training function
def train_epoch(model, dataloader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    total_tokens = 0

    for src_pad, src_lens, tgt_pad, tgt_lens in tqdm(dataloader, desc="Training"):
        src_pad = src_pad.to(device)
        tgt_pad = tgt_pad.to(device)

        optimizer.zero_grad()

        # Forward pass
        logits = model(src_pad, src_lens, tgt_pad)  # (B, T_tgt-1, V)

        # Target is tgt_pad shifted by 1 (exclude BOS, include EOS)
        targets = tgt_pad[:, 1:]  # (B, T_tgt-1)

        # Reshape for loss computation
        B, T, V = logits.size()
        loss = criterion(logits.reshape(B * T, V), targets.reshape(B * T))

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        # Count non-padding tokens
        non_pad = (targets != PAD_IDX_TGT).sum().item()
        total_loss += loss.item() * non_pad
        total_tokens += non_pad

    return total_loss / total_tokens

def evaluate(model, dataloader, criterion, device):
    model.eval()
    total_loss = 0
    total_tokens = 0

    with torch.no_grad():
        for src_pad, src_lens, tgt_pad, tgt_lens in tqdm(dataloader, desc="Evaluating"):
            src_pad = src_pad.to(device)
            tgt_pad = tgt_pad.to(device)

            logits = model(src_pad, src_lens, tgt_pad)
            targets = tgt_pad[:, 1:]

            B, T, V = logits.size()
            loss = criterion(logits.reshape(B * T, V), targets.reshape(B * T))

            non_pad = (targets != PAD_IDX_TGT).sum().item()
            total_loss += loss.item() * non_pad
            total_tokens += non_pad

    return total_loss / total_tokens

# Training loop
train_losses = []
val_losses = []

print("Starting training...")
for epoch in range(NUM_EPOCHS):
    train_loss = train_epoch(model, train_loader, optimizer, criterion, device)
    val_loss = evaluate(model, val_loader, criterion, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    print(f"Epoch {epoch+1}/{NUM_EPOCHS} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")

# Plot loss curves
plt.figure(figsize=(10, 6))
plt.plot(range(1, NUM_EPOCHS + 1), train_losses, label='Train Loss')
plt.plot(range(1, NUM_EPOCHS + 1), val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (per token)')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Using device: cuda
# Starting training...
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 1/25 | Train Loss: 4.6049 | Val Loss: 3.6132
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 2/25 | Train Loss: 3.5172 | Val Loss: 3.0759
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 3/25 | Train Loss: 3.0615 | Val Loss: 2.8798
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 4/25 | Train Loss: 2.8015 | Val Loss: 2.8044
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 5/25 | Train Loss: 2.6211 | Val Loss: 2.7337
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 6/25 | Train Loss: 2.4851 | Val Loss: 2.7052
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 7/25 | Train Loss: 2.3874 | Val Loss: 2.6454
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 8/25 | Train Loss: 2.3085 | Val Loss: 2.6414
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 9/25 | Train Loss: 2.2418 | Val Loss: 2.6377
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 10/25 | Train Loss: 2.1888 | Val Loss: 2.6275
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 11/25 | Train Loss: 2.1434 | Val Loss: 2.6312
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 12/25 | Train Loss: 2.1021 | Val Loss: 2.6302
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 13/25 | Train Loss: 2.0636 | Val Loss: 2.6438
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 14/25 | Train Loss: 2.0345 | Val Loss: 2.6416
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 15/25 | Train Loss: 2.0018 | Val Loss: 2.6531
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 16/25 | Train Loss: 1.9738 | Val Loss: 2.6536
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 17/25 | Train Loss: 1.9492 | Val Loss: 2.6525
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 18/25 | Train Loss: 1.9269 | Val Loss: 2.6627
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 19/25 | Train Loss: 1.9086 | Val Loss: 2.6560
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 20/25 | Train Loss: 1.8950 | Val Loss: 2.6808
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 21/25 | Train Loss: 1.8717 | Val Loss: 2.6634
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 22/25 | Train Loss: 1.8570 | Val Loss: 2.6626
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 23/25 | Train Loss: 1.8433 | Val Loss: 2.6746
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 24/25 | Train Loss: 1.8252 | Val Loss: 2.6860
# Training:   0%|          | 0/3237 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 25/25 | Train Loss: 1.8122 | Val Loss: 2.7074

# %% [markdown]
# #### BLEU Evaluation
#
# After training is complete, we evaluate the translation quality of the model using the **BLEU (Bilingual Evaluation Understudy)** score.
#
# BLEU is a **corpus-level** evaluation metric for machine translation. It is computed by comparing a set of model-generated translations (*hypotheses*) against ground-truth translations (*references*). BLEU measures the overlap of n-grams (typically 1- to 4-grams) between the hypotheses and references, and applies a **brevity penalty** to discourage
# overly short translations.
#
# Importantly, BLEU is **not computed during training** and is **not differentiable**. It is used purely for evaluation.
#
# </br>
# </br>
#
# **How BLEU is computed in this question**
#
# 1. The trained model is used to **decode full translations** for each source sentence in the **test set**, using an autoregressive decoding strategy. For this part, use beam search.
# 2. For each test example, the generated translation is treated as the hypothesis, and the ground-truth English sentence is treated as the reference.
# 3. The BLEU score is computed over the entire test set (corpus-level BLEU), and the final BLEU score is reported.
#
#
# **Implement a BLEU evaluation routine** that decodes translations for the test set using beam search and computes the corpus-level BLEU score against the reference translations.
#
# > You may use your implementation of beam search from Q1.

# %%
from collections import Counter
import math

def beam_search_decode(model, src_sentence, src_vocab, tgt_vocab, device,
                       beam_size=5, max_len=50):
    """Decode a single source sentence using beam search."""
    model.eval()

    BOS_IDX = tgt_vocab.stoi[BOS_TOKEN]
    EOS_IDX = tgt_vocab.stoi[EOS_TOKEN]

    with torch.no_grad():
        # Encode source
        src_ids = src_vocab.encode(src_sentence)
        src_pad = torch.tensor([src_ids], dtype=torch.long).to(device)
        src_lens = torch.tensor([len(src_ids)]).to(device)

        enc_hiddens, (h_n, c_n) = model.encoder(src_pad, src_lens)
        h0, c0 = model.dec_init(h_n, c_n)

        # Initialize beams: (log_prob, token_ids, h, c)
        beams = [(0.0, [BOS_IDX], h0, c0)]
        completed = []

        for _ in range(max_len):
            new_beams = []

            for log_prob, tokens, h, c in beams:
                if tokens[-1] == EOS_IDX:
                    completed.append((log_prob, tokens))
                    continue

                # Get last token embedding
                last_tok = torch.tensor([[tokens[-1]]], dtype=torch.long).to(device)
                emb = model.decoder.dropout(model.decoder.embedding(last_tok))
                emb = emb.squeeze(1)

                # LSTM cell forward
                h_new, c_new = model.decoder.lstm_cell(emb, (h, c))

                # Attention
                context, _ = model.decoder.attention(h_new, enc_hiddens, src_lens)

                # Combine and project
                combined = torch.cat([h_new, context], dim=1)
                attn_vec = torch.tanh(model.decoder.attn_combine(combined))

                # Get logits
                logits = model.out_proj(attn_vec)
                log_probs_out = F.log_softmax(logits, dim=1)

                # Get top-k
                topk_log_probs, topk_indices = log_probs_out.topk(beam_size, dim=1)

                for i in range(beam_size):
                    new_tok = topk_indices[0, i].item()
                    new_log_prob = log_prob + topk_log_probs[0, i].item()
                    new_tokens = tokens + [new_tok]
                    new_beams.append((new_log_prob, new_tokens, h_new, c_new))

            new_beams.sort(key=lambda x: x[0], reverse=True)
            beams = new_beams[:beam_size]

            if not beams:
                break

        for log_prob, tokens, _, _ in beams:
            completed.append((log_prob, tokens))

        if completed:
            completed.sort(key=lambda x: x[0], reverse=True)
            best_tokens = completed[0][1]
        else:
            best_tokens = [BOS_IDX, EOS_IDX]

        return tgt_vocab.decode(best_tokens)


def compute_bleu(hypotheses, references, max_n=4):
    """Compute corpus-level BLEU score."""

    def get_ngrams(tokens, n):
        return [tuple(tokens[i:i+n]) for i in range(len(tokens) - n + 1)]

    def count_ngrams(tokens, n):
        return Counter(get_ngrams(tokens, n))

    precisions = []

    for n in range(1, max_n + 1):
        total_clipped = 0
        total_count = 0

        for hyp, ref in zip(hypotheses, references):
            hyp_tokens = hyp.split()
            ref_tokens = ref.split()

            hyp_ngrams = count_ngrams(hyp_tokens, n)
            ref_ngrams = count_ngrams(ref_tokens, n)

            for ngram, count in hyp_ngrams.items():
                clipped_count = min(count, ref_ngrams.get(ngram, 0))
                total_clipped += clipped_count

            total_count += max(len(hyp_tokens) - n + 1, 0)

        precision = total_clipped / total_count if total_count > 0 else 0
        precisions.append(precision)

    # Brevity penalty
    hyp_len = sum(len(h.split()) for h in hypotheses)
    ref_len = sum(len(r.split()) for r in references)

    if hyp_len == 0:
        return 0.0

    bp = math.exp(1 - ref_len / hyp_len) if hyp_len <= ref_len else 1.0

    # Geometric mean
    if all(p > 0 for p in precisions):
        bleu = bp * math.exp(sum(math.log(p) for p in precisions) / len(precisions))
    else:
        bleu = 0.0

    return bleu


# ============================================================
# RUN BLEU EVALUATION
# ============================================================

print("Evaluating on test set with beam search...")
all_hypotheses = []
all_references = []

for i in tqdm(range(len(test_pt)), desc="Decoding"):
    src_sentence = test_pt[i]
    ref_sentence = test_en[i]

    hyp_sentence = beam_search_decode(
        model, src_sentence, pt_vocab, en_vocab, device, beam_size=5, max_len=50
    )

    all_hypotheses.append(hyp_sentence)
    all_references.append(ref_sentence)

# Compute BLEU
bleu_score = compute_bleu(all_hypotheses, all_references)
print(f"\nCorpus-level BLEU score: {bleu_score:.4f}")

# Show examples
print("\n" + "=" * 60)
print("Example Translations")
print("=" * 60)

for i in range(5):
    print(f"\nExample {i+1}")
    print("-" * 40)
    print(f"Source (PT):     {test_pt[i]}")
    print(f"Reference (EN):  {test_en[i]}")
    print(f"Prediction (EN): {all_hypotheses[i]}")
# Out:
# Evaluating on test set with beam search...
# Decoding:   0%|          | 0/1803 [00:00<?, ?it/s]
# Corpus-level BLEU score: 0.2410
#
# ============================================================
# Example Translations
# ============================================================
#
# Example 1
# ----------------------------------------
# Source (PT):     depois , podem fazer-se e testar-se previsões .
# Reference (EN):  then , predictions can be made and tested .
# Prediction (EN): and then you can turn back and eat predictions .
#
# Example 2
# ----------------------------------------
# Source (PT):     forçou a parar múltiplos laboratórios que ofereciam testes brca .
# Reference (EN):  it had forced multiple labs that were offering brca testing to stop .
# Prediction (EN): they 're playing multiple multiple labs .
#
# Example 3
# ----------------------------------------
# Source (PT):     as formigas são um exemplo clássico ; as operárias trabalham para as rainhas e vice-versa .
# Reference (EN):  ants are a classic example ; workers work for queens and queens work for workers .
# Prediction (EN): the ants are a classic example ; it allowed us to work for <unk> and vice versa .
#
# Example 4
# ----------------------------------------
# Source (PT):     uma em cada cem crianças no mundo nascem com uma doença cardíaca .
# Reference (EN):  one of every hundred children born worldwide has some kind of heart disease .
# Prediction (EN): one in every wonderful hundred children in the arab world with a heart disease .
#
# Example 5
# ----------------------------------------
# Source (PT):     neste momento da sua vida , ela está a sofrer de sida no seu expoente máximo e tinha pneumonia .
# Reference (EN):  at this point in her life , she 's suffering with full-blown aids and had pneumonia .
# Prediction (EN): in this point of his life , she 's suffering from aids in her <unk> and she was scared .

# %% [markdown]
# ### Understanding & Reflection Questions

# %% [markdown]
# Answer the following questions in your own words.
# Your answers should demonstrate conceptual understanding rather than
# code-level details.
#
# 1. **Parallel Corpus Understanding**
#    What is a *parallel corpus* in machine translation?
#    In this assignment, what constitutes a single training example, and why is this format appropriate for NMT?
#
#    <font color=red>
#    A parallel corpus is a dataset containing sentence pairs where each source sentence is aligned with its translation in the target language. In this assignment, a single training example consists of a Portuguese sentence paired with its English translation. This format is appropriate for NMT because it provides supervised training signal - the model learns to map source sequences to target sequences by observing many paired examples.
#    </font>
#
#
# 2. **Vocabulary & Special Tokens**
#    Which special tokens are required for training and decoding (e.g., `<pad>`, `<unk>`, `<sos>`, `<eos>`)?
#    Explain the role of each token in **both** training (teacher forcing) and inference (decoding).
#
#     <font color=red>
#    - `<pad>`: Used to fill shorter sequences in batches to create uniform tensor dimensions. During training, padding positions are ignored in loss computation. During inference, padding is used when batching multiple inputs.<br>
#   - `<unk>`: Represents out-of-vocabulary words. During training, rare words are mapped to `<unk>`. During inference, unknown words in input are also mapped to `<unk>`.<br>
#   - `<bos>` (or `<sos>`): Marks the beginning of a sequence. During training with teacher forcing, it's the first input to the decoder. During inference, it initializes autoregressive generation.<br>
#   - `<eos>`: Marks the end of a sequence. During training, the model learns to predict `<eos>` at the end. During inference, generation stops when `<eos>` is predicted.
#    </font>
#
# 3. **Encoder–Decoder Interface**
#    Our encoder is a **bidirectional** LSTM while our decoder is **unidirectional**.
#    Explain why this creates a mismatch in the final states, and how we resolve it to initialize the decoder.
#
#     <font color=red>
#     The bidirectional LSTM encoder produces two final hidden states: one from the forward pass and one from the backward pass, each of shape (B, H). The unidirectional decoder expects a single hidden state of shape (B, H). We resolve this mismatch by concatenating the forward and backward states (giving 2H) and projecting through a linear layer back to H dimensions. This allows the decoder to leverage information from both directions of the source sentence.
#    </font>
#
# 4. **Attention Mechanism (High-level)**
#    What problem does attention solve in neural machine translation?
#    Describe (in words) how the decoder uses attention at a single timestep to choose which source positions to focus on.
#
#    <font color=red>
#    Attention solves the information bottleneck problem where a fixed-size context vector must encode the entire source sentence. At each timestep, the decoder computes similarity scores between its current hidden state and all encoder hidden states. These scores are normalized via softmax to obtain attention weights. The context vector is computed as a weighted sum of encoder states, allowing the decoder to dynamically focus on relevant source positions for each target word.
#    </font>
#
# 5. **Training vs. Decoding**
#    During training we use teacher forcing, but at test time the model must generate translations autoregressively.
#    Explain the difference between these two settings, and describe one potential consequence of this mismatch.
#
#    <font color=red>
#    During training (teacher forcing), the decoder receives the ground-truth previous token as input at each step, regardless of its own predictions. During inference, the decoder must use its own predictions as input for subsequent steps. This mismatch can cause "exposure bias" - the model never sees its own errors during training, so it may struggle to recover from mistakes during inference, leading to error propagation.
#    </font>
#
# 6. **BLEU Interpretation**
#    What does BLEU measure at a high level, and why is it computed at the **corpus level** rather than per sentence?
#    Briefly explain how the decoding strategy (greedy vs. beam search) can affect BLEU.
#
#    <font color=red>
#    BLEU measures the overlap of n-grams (typically 1 to 4-grams) between generated translations and reference translations, with a brevity penalty for short outputs. It's computed at the corpus level because individual sentence BLEU scores are unreliable (especially for short sentences where precision can be 0 or 1). Beam search typically improves BLEU over greedy decoding because it explores multiple hypotheses, finding translations that better match reference n-grams.
#    </font>
#
# 7. **Length Effects**
#    In practice, how does translation quality tend to change as sentence length increases?
#    Give one reason why longer sentences are harder for sequence-to-sequence models.
#
#   <font color=red>
#    Translation quality typically degrades as sentence length increases because:
#     1. Long-range dependencies are harder to capture, even with attention <br>
#     2. Error propagation accumulates over more decoding steps  <br>
#     3. The encoder must compress more information  <br>
#     4. Rare word combinations become more likely in longer sentences  <br>
#     One key reason: RNN/LSTM hidden states have limited capacity to maintain information over many time steps, leading to information loss for long sequences.
#    </font>
